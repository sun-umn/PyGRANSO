# %%
# %cd ..
# Out:
# /users/5/dever120/PyGRANSO

# %% [markdown]
# # Trace Optimization
#
# Trace optimization with orthogonal constraints taken from: Effrosini Kokiopoulou, Jie Chen, and Yousef Saad. "Trace optimization and eigenproblems in dimension reduction methods." Numerical Linear Algebra with Applications 18.3 (2011): 565-602.

# %% [markdown]
# ## Problem Description
# Given a symmetric matrix $A$ of dimension $n\times n$, and an arbitrary unitary matrix $V$ of dimension $n\times d$.
#
# The trace of $V^TAV$ is maximized when $V$ is an orthogonal basis of the eigenspace associated with the (algebraically) largest eigenvalues.
#
# If eigenvalues are labeled decreasingly and $u_1,...,u_d$ are eigenvectors associated with the first $d$ eigenvalues $\lambda_1,...,\lambda_d$, and $U = [u_1,...,u_d]$ with $U^TU=I$, then,
#
# $$\max_{V \in R^{n\times d}, V^TV=I} \text{Tr}[V^TAV]=\text{Tr}[U^TAU]=\lambda_1+...+\lambda_d$$

# %% [markdown]
# ## Modules Importing
# Import all necessary modules and add PyGRANSO src folder to system path.

# %%
import time
import torch
import sys

## Adding PyGRANSO directories. Should be modified by user
sys.path.append("/users/5/dever120/PyGRANSO")
from pygranso.pygranso import pygranso
from pygranso.pygransoStruct import pygransoStruct

# %% [markdown]
# ## Data Initialization
# Specify torch device, and generate data
#
# Use GPU for this problem. If no cuda device available, please set *device = torch.device('cpu')*

# %%
device = torch.device("cpu")
n = 5
d = 1
torch.manual_seed(0)

# All the user-provided data (vector/matrix/tensor) must be in torch tensor format.
# As PyTorch tensor is single precision by default, one must explicitly set `dtype=torch.double`.
# Also, please make sure the device of provided torch tensor is the same as opts.torch_device.
A = torch.randn(n, n).to(device=device, dtype=torch.double)
A = (A + A.T) / 2
L, U = torch.linalg.eig(A)
L, U = L.to(dtype=torch.double), U.to(dtype=torch.double)
index = torch.argsort(L, descending=True)
U = U[:, index[0:d]]
# Out:
# /tmp/ipykernel_2502820/2202218492.py:12: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at /pytorch/aten/src/ATen/native/Copy.cpp:307.)
#   L, U = L.to(dtype=torch.double), U.to(dtype=torch.double)

# %% [markdown]
# ## Function Set-Up
#
# Encode the optimization variables, and objective and constraint functions.
#
# Note: please strictly follow the format of comb_fn, which will be used in the PyGRANSO main algortihm.

# %%
# variables and corresponding dimensions.
var_in = {"V": [n, d]}


def user_fn(X_struct, A, d):
    V = X_struct.V

    # objective function
    f = -torch.trace(V.T @ A @ V)

    # inequality constraint, matrix form
    ci = None

    # equality constraint
    ce = pygransoStruct()
    ce.c1 = V.T @ V - torch.eye(d).to(device=device, dtype=torch.double)

    return [f, ci, ce]


comb_fn = lambda X_struct: user_fn(X_struct, A, d)

# %% [markdown]
# ## User Options
# Specify user-defined options for PyGRANSO

# %%
opts = pygransoStruct()
opts.torch_device = device
opts.print_frequency = 1
opts.maxit = 3000

# %% [markdown]
# ## Main Algorithm

# %%
start = time.time()
cpu_soln = pygranso(var_spec=var_in, combined_fn=comb_fn, user_opts=opts)
end = time.time()
print("Total Wall Time: {}s".format(end - start))

V = torch.reshape(cpu_soln.final.x, (n, d))

rel_dist = torch.norm(V @ V.T - U @ U.T) / torch.norm(U @ U.T)
print("torch.norm(V @ V.T - U @ U.T) / torch.norm(U @ U.T) = {}".format(rel_dist))

print("torch.trace(V.T @ A @ V) = {}".format(torch.trace(V.T @ A @ V)))
print("torch.trace(U.T @ A @ U) = {}".format(torch.trace(U.T @ A @ U)))
print("sum of first d eigvals = {}".format(torch.sum(L[index[0:d]])))
print("sorted eigs = {}".format(L[index]))
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                                             ║
# Version 1.2.0                                                                                                    ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang                                  ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                                          ║
#  # of variables                     :   5                                                                        ║
#  # of inequality constraints        :   0                                                                        ║
#  # of equality constraints          :   1                                                                        ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#    0 ║ 1.000000 │  1.16724813601 ║ -2.14592113443 ║   -  │ 3.313169 ║ -  │     1 │ 0.000000 ║     1 │ 4.801284   ║
# Polishing not needed - no active set detected at optimal point
#    1 ║ 1.000000 │ -4.18220640118 ║ -27.2345373313 ║   -  │ 23.05233 ║ S  │     1 │ 1.000000 ║     1 │ 19.60748   ║
# Polishing not needed - no active set detected at optimal point
#    2 ║ 0.810000 │ -7.44513089341 ║ -25.7524524611 ║   -  │ 13.41436 ║ S  │     1 │ 1.000000 ║     1 │ 2.119321   ║
# Polishing not needed - no active set detected at optimal point
#    3 ║ 0.478297 │ -3.36403570563 ║ -29.7615131867 ║   -  │ 10.87080 ║ S  │     1 │ 1.000000 ║     1 │ 0.807332   ║
# Polishing not needed - no active set detected at optimal point
#    4 ║ 0.313811 │  0.44260646755 ║ -29.8199400438 ║   -  │ 9.800420 ║ S  │     1 │ 1.000000 ║     1 │ 0.181373   ║
#    5 ║ 0.313811 │ -0.05159283053 ║ -25.9178254403 ║   -  │ 8.081695 ║ S  │     2 │ 2.000000 ║     1 │ 0.266675   ║
#    6 ║ 0.313811 │ -0.60015959521 ║ -19.8021105233 ║   -  │ 5.613953 ║ S  │     2 │ 2.000000 ║     1 │ 0.129813   ║
#    7 ║ 0.313811 │ -0.74007491793 ║ -15.7240418418 ║   -  │ 4.194296 ║ S  │     1 │ 1.000000 ║     1 │ 0.073206   ║
#    8 ║ 0.313811 │ -0.80534295483 ║ -10.5540665925 ║   -  │ 2.506635 ║ S  │     3 │ 4.000000 ║     1 │ 0.096243   ║
#    9 ║ 0.313811 │ -0.90562463200 ║ -3.96127832617 ║   -  │ 0.337466 ║ S  │     3 │ 1.500000 ║     1 │ 0.109112   ║
# Polishing not needed - no active set detected at optimal point
#   10 ║ 0.313811 │ -0.94306331782 ║ -3.09440966016 ║   -  │ 0.027995 ║ S  │     1 │ 1.000000 ║     1 │ 0.036484   ║
# Polishing not needed - no active set detected at optimal point
#   11 ║ 0.313811 │ -0.95168907673 ║ -3.04557834593 ║   -  │ 0.004046 ║ S  │     1 │ 1.000000 ║     1 │ 0.016092   ║
# Polishing not needed - no active set detected at optimal point
#   12 ║ 0.313811 │ -0.95404206443 ║ -3.04284283001 ║   -  │ 8.34e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010167   ║
# Polishing not needed - no active set detected at optimal point
#   13 ║ 0.313811 │ -0.95488755011 ║ -3.04425497591 ║   -  │ 4.32e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.003923   ║
# Polishing not needed - no active set detected at optimal point
#   14 ║ 0.313811 │ -0.95497194333 ║ -3.04323398616 ║   -  │ 2.71e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.001371   ║
# Polishing not needed - no active set detected at optimal point
#   15 ║ 0.313811 │ -0.95498874787 ║ -3.04321724294 ║   -  │ 5.07e-06 ║ S  │     1 │ 1.000000 ║     1 │ 8.65e-04   ║
# Polishing not needed - no active set detected at optimal point
#   16 ║ 0.313811 │ -0.95499959494 ║ -3.04325102043 ║   -  │ 4.82e-06 ║ S  │     1 │ 1.000000 ║     1 │ 6.98e-04   ║
# Polishing not needed - no active set detected at optimal point
#   17 ║ 0.313811 │ -0.95500308923 ║ -3.04325221318 ║   -  │ 1.70e-06 ║ S  │     1 │ 1.000000 ║     1 │ 3.20e-04   ║
# Polishing not needed - no active set detected at optimal point
#   18 ║ 0.313811 │ -0.95500354042 ║ -3.04324890133 ║   -  │ 2.11e-07 ║ S  │     1 │ 1.000000 ║     1 │ 8.22e-05   ║
# Polishing not needed - no active set detected at optimal point
#   19 ║ 0.313811 │ -0.95500356428 ║ -3.04324833552 ║   -  │ 9.93e-09 ║ S  │     1 │ 1.000000 ║     2 │ 2.76e-05   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   20 ║ 0.313811 │ -0.95500356476 ║ -3.04324830572 ║   -  │ 1.06e-10 ║ S  │     7 │ 1.031250 ║     2 │ 7.11e-06   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   21 ║ 0.313811 │ -0.95500356497 ║ -3.04324830605 ║   -  │ 4.25e-12 ║ SI │     1 │ 1.000000 ║     3 │ 1.15e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   22 ║ 0.313811 │ -0.95500356497 ║ -3.04324830605 ║   -  │ 4.32e-12 ║ SI │     2 │ 0.500000 ║     4 │ 1.51e-05   ║
# Polishing not needed - no active set detected at optimal point
#   23 ║ 0.313811 │ -0.95500356497 ║ -3.04324830605 ║   -  │ 4.31e-12 ║ S  │     9 │ 0.003906 ║     5 │ 1.51e-06   ║
# Polishing not needed - no active set detected at optimal point
#   24 ║ 0.313811 │ -0.95500356497 ║ -3.04324830604 ║   -  │ 6.15e-14 ║ S  │     8 │ 1.015625 ║     6 │ 2.81e-07   ║
# Polishing not needed - no active set detected at optimal point
#   25 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 1.73e-14 ║ S  │    20 │ 1.91e-06 ║     7 │ 0.002650   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   26 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 2.40e-13 ║ SI │     2 │ 0.500000 ║     8 │ 2.01e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   27 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 5.26e-14 ║ SI │     1 │ 1.000000 ║     9 │ 1.71e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   28 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 5.26e-14 ║ SI │     2 │ 0.500000 ║    10 │ 2.76e-07   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   29 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 1.47e-14 ║ SI │     1 │ 1.000000 ║    10 │ 1.15e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   30 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 1.89e-14 ║ SI │     2 │ 0.500000 ║    10 │ 1.14e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   31 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 1.15e-14 ║ SI │     2 │ 0.500000 ║    10 │ 1.14e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   32 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 1.11e-15 ║ SI │     1 │ 1.000000 ║    10 │ 1.14e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   33 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 1.55e-15 ║ SI │     2 │ 0.500000 ║    10 │ 1.14e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   34 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 0.000000 ║ SI │     1 │ 1.000000 ║    10 │ 1.14e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   35 ║ 0.282430 │ -0.85950320847 ║ -3.04324830604 ║   -  │ 6.66e-16 ║ SI │     2 │ 0.500000 ║    10 │ 1.14e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                                            ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                                   ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#    F ║          │                ║ -3.04324830604 ║   -  │ 6.66e-16 ║    │       │          ║       │            ║
#    B ║          │                ║ -3.04324890133 ║   -  │ 2.11e-07 ║    │       │          ║       │            ║
#   MF ║          │                ║ -3.04324830604 ║   -  │ 0.000000 ║    │       │          ║       │            ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Iterations:              35                                                                                      ║
# Function evaluations:    104                                                                                     ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy Wolfe conditions at a   ║
# feasible point (to tolerances).  This may be an indication that approximate stationarity has been attained.      ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# Total Wall Time: 0.6323885917663574s
# torch.norm(V @ V.T - U @ U.T) / torch.norm(U @ U.T) = 7.586456403606953e-09
# torch.trace(V.T @ A @ V) = 3.0432483060418933
# torch.trace(U.T @ A @ U) = 3.043248306041891
# sum of first d eigvals = 3.0432483060418907
# sorted eigs = tensor([ 3.0432,  0.8890, -0.4730, -0.9598, -1.8722], dtype=torch.float64)

# %% [markdown]
# ## CUDA Computations

# %%
device = torch.device("cuda")
n = 5
d = 1
torch.manual_seed(0)

# All the user-provided data (vector/matrix/tensor) must be in torch tensor format.
# As PyTorch tensor is single precision by default, one must explicitly set `dtype=torch.double`.
# Also, please make sure the device of provided torch tensor is the same as opts.torch_device.
A = torch.randn(n, n).to(device=device, dtype=torch.double)
A = (A + A.T) / 2
L, U = torch.linalg.eig(A)
L, U = L.to(dtype=torch.double), U.to(dtype=torch.double)
index = torch.argsort(L, descending=True)
U = U[:, index[0:d]]

# %%
# variables and corresponding dimensions.
var_in = {"V": [n, d]}


def user_fn(X_struct, A, d):
    V = X_struct.V

    # objective function
    f = -torch.trace(V.T @ A @ V)

    # inequality constraint, matrix form
    ci = None

    # equality constraint
    ce = pygransoStruct()
    ce.c1 = V.T @ V - torch.eye(d).to(device=device, dtype=torch.double)

    return [f, ci, ce]


comb_fn = lambda X_struct: user_fn(X_struct, A, d)

# %%
opts = pygransoStruct()
opts.torch_device = device
opts.print_frequency = 1
opts.maxit = 3000

# %%
start = time.time()
cuda_soln = pygranso(var_spec=var_in, combined_fn=comb_fn, user_opts=opts)
end = time.time()
print("Total Wall Time: {}s".format(end - start))

V = torch.reshape(cuda_soln.final.x, (n, d))

rel_dist = torch.norm(V @ V.T - U @ U.T) / torch.norm(U @ U.T)
print("torch.norm(V @ V.T - U @ U.T) / torch.norm(U @ U.T) = {}".format(rel_dist))

print("torch.trace(V.T @ A @ V) = {}".format(torch.trace(V.T @ A @ V)))
print("torch.trace(U.T @ A @ U) = {}".format(torch.trace(U.T @ A @ U)))
print("sum of first d eigvals = {}".format(torch.sum(L[index[0:d]])))
print("sorted eigs = {}".format(L[index]))
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                                             ║
# Version 1.2.0                                                                                                    ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang                                  ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                                          ║
#  # of variables                     :   5                                                                        ║
#  # of inequality constraints        :   0                                                                        ║
#  # of equality constraints          :   1                                                                        ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#    0 ║ 1.000000 │  1.16724813601 ║ -2.14592113443 ║   -  │ 3.313169 ║ -  │     1 │ 0.000000 ║     1 │ 4.801284   ║
# Polishing not needed - no active set detected at optimal point
#    1 ║ 1.000000 │ -4.18220679991 ║ -27.2345378373 ║   -  │ 23.05233 ║ S  │     1 │ 1.000000 ║     1 │ 19.60748   ║
# Polishing not needed - no active set detected at optimal point
#    2 ║ 0.810000 │ -7.44513100529 ║ -25.7524531330 ║   -  │ 13.41436 ║ S  │     1 │ 1.000000 ║     1 │ 2.119321   ║
#    3 ║ 0.478297 │ -3.36403538793 ║ -29.7615078146 ║   -  │ 10.87080 ║ S  │     1 │ 1.000000 ║     1 │ 0.807332   ║
# Polishing not needed - no active set detected at optimal point
#    4 ║ 0.313811 │  0.44260638709 ║ -29.8199316262 ║   -  │ 9.800417 ║ S  │     1 │ 1.000000 ║     1 │ 0.181373   ║
#    5 ║ 0.313811 │ -0.05159302879 ║ -25.9178071719 ║   -  │ 8.081689 ║ S  │     2 │ 2.000000 ║     1 │ 0.266675   ║
#    6 ║ 0.313811 │ -0.60015984192 ║ -19.8020918486 ║   -  │ 5.613946 ║ S  │     2 │ 2.000000 ║     1 │ 0.129813   ║
#    7 ║ 0.313811 │ -0.74007516157 ║ -15.7240249785 ║   -  │ 4.194290 ║ S  │     1 │ 1.000000 ║     1 │ 0.073206   ║
#    8 ║ 0.313811 │ -0.80534315782 ║ -10.5540578029 ║   -  │ 2.506632 ║ S  │     3 │ 4.000000 ║     1 │ 0.096243   ║
#    9 ║ 0.313811 │ -0.90562473167 ║ -3.96127301421 ║   -  │ 0.337465 ║ S  │     3 │ 1.500000 ║     1 │ 0.109112   ║
#   10 ║ 0.313811 │ -0.94306314111 ║ -3.09442386400 ║   -  │ 0.028000 ║ S  │     1 │ 1.000000 ║     1 │ 0.036483   ║
# Polishing not needed - no active set detected at optimal point
#   11 ║ 0.313811 │ -0.95168918167 ║ -3.04556942883 ║   -  │ 0.004043 ║ S  │     1 │ 1.000000 ║     1 │ 0.016092   ║
#   12 ║ 0.313811 │ -0.95404209250 ║ -3.04284115011 ║   -  │ 8.34e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010167   ║
#   13 ║ 0.313811 │ -0.95488744927 ║ -3.04426178092 ║   -  │ 4.34e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.003923   ║
#   14 ║ 0.313811 │ -0.95497192878 ║ -3.04323496286 ║   -  │ 2.74e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.001371   ║
#   15 ║ 0.313811 │ -0.95498860889 ║ -3.04322662737 ║   -  │ 8.15e-06 ║ S  │     1 │ 1.000000 ║     1 │ 8.65e-04   ║
#   16 ║ 0.313811 │ -0.95499937821 ║ -3.04326565765 ║   -  │ 9.63e-06 ║ S  │     1 │ 1.000000 ║     1 │ 6.98e-04   ║
#   17 ║ 0.313811 │ -0.95500282430 ║ -3.04327012750 ║   -  │ 7.59e-06 ║ S  │     1 │ 1.000000 ║     1 │ 3.20e-04   ║
# Polishing not needed - no active set detected at optimal point
#   18 ║ 0.313811 │ -0.95500326477 ║ -3.04326754440 ║   -  │ 6.34e-06 ║ S  │     1 │ 1.000000 ║     1 │ 8.22e-05   ║
# Polishing not needed - no active set detected at optimal point
#   19 ║ 0.313811 │ -0.95500330294 ║ -3.04324789763 ║   -  │ 1.34e-07 ║ S  │     6 │ 0.968750 ║     2 │ 4.83e-05   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   20 ║ 0.254187 │ -0.77355271154 ║ -3.04324781510 ║   -  │ 5.13e-08 ║ S  │     5 │ 0.062500 ║     1 │ 0.002893   ║
#   21 ║ 0.150095 │ -0.45677515527 ║ -3.04324878023 ║   -  │ 1.61e-07 ║ S  │     2 │ 0.500000 ║     1 │ 0.014233   ║
#   22 ║ 0.150095 │ -0.45677523542 ║ -3.04324825212 ║   -  │ 1.10e-09 ║ S  │     1 │ 1.000000 ║     1 │ 0.004538   ║
#   23 ║ 0.098477 │ -0.29969023165 ║ -3.04324827202 ║   -  │ 2.99e-09 ║ S  │     3 │ 0.250000 ║     2 │ 4.48e-05   ║
#   24 ║ 0.098477 │ -0.29969023207 ║ -3.04324830175 ║   -  │ 5.50e-09 ║ S  │     4 │ 0.125000 ║     3 │ 3.52e-04   ║
# Polishing not needed - no active set detected at optimal point
#   25 ║ 0.034337 │ -0.10449552038 ║ -3.04324827707 ║   -  │ 3.32e-09 ║ SI │     3 │ 0.250000 ║     4 │ 1.28e-05   ║
#   26 ║ 0.034337 │ -0.10449552284 ║ -3.04324830903 ║   -  │ 1.96e-09 ║ S  │     5 │ 6.000000 ║     4 │ 8.28e-06   ║
#   27 ║ 0.011973 │ -0.03643533573 ║ -3.04324830078 ║   -  │ 7.57e-10 ║ SI │     6 │ 0.031250 ║     5 │ 3.78e-06   ║
#   28 ║ 0.011973 │ -0.03643533584 ║ -3.04324830802 ║   -  │ 7.35e-10 ║ S  │     5 │ 16.00000 ║     5 │ 1.58e-06   ║
#   29 ║ 0.011973 │ -0.03643533648 ║ -3.04324830116 ║   -  │ 6.33e-12 ║ QN │     1 │ 1.000000 ║     4 │ 1.43e-06   ║
#   30 ║ 0.011973 │ -0.03643533568 ║ -3.04324830042 ║   -  │ 7.99e-10 ║ QN │     1 │ 1.000000 ║     5 │ 1.09e-06   ║
#   31 ║ 0.011973 │ -0.03643533621 ║ -3.04324830679 ║   -  │ 3.45e-10 ║ S  │     7 │ 24.00000 ║     4 │ 1.23e-06   ║
#   32 ║ 0.011973 │ -0.03643533596 ║ -3.04324830062 ║   -  │ 5.20e-10 ║ QN │     1 │ 1.000000 ║     4 │ 1.26e-06   ║
#   33 ║ 0.004175 │ -0.01270421622 ║ -3.04324830243 ║   -  │ 7.30e-11 ║ SI │     8 │ 0.007812 ║     5 │ 6.20e-07   ║
#   34 ║ 0.001456 │ -0.00442968628 ║ -3.04324830209 ║   -  │ 4.00e-11 ║ SI │    10 │ 0.001953 ║     6 │ 2.84e-07   ║
#   35 ║ 0.001456 │ -0.00442968631 ║ -3.04324830349 ║   -  │ 1.19e-11 ║ S  │     7 │ 24.00000 ║     7 │ 2.75e-07   ║
#   36 ║ 5.08e-04 │ -0.00154453611 ║ -3.04324830341 ║   -  │ 1.17e-11 ║ SI │    13 │ 2.44e-04 ║     8 │ 8.23e-08   ║
#   37 ║ 5.08e-04 │ -0.00154453611 ║ -3.04324830403 ║   -  │ 3.05e-12 ║ S  │     6 │ 32.00000 ║     9 │ 7.81e-08   ║
#   38 ║ 5.08e-04 │ -0.00154453611 ║ -3.04324830299 ║   -  │ 6.94e-12 ║ QN │     1 │ 1.000000 ║    10 │ 9.93e-08   ║
#   39 ║ 5.08e-04 │ -0.00154453612 ║ -3.04324830320 ║   -  │ 3.13e-13 ║ S  │     6 │ 32.00000 ║    10 │ 4.09e-08   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                                            ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                                   ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#    F ║          │                ║ -3.04324830320 ║   -  │ 3.13e-13 ║    │       │          ║       │            ║
#    B ║          │                ║ -3.04324979963 ║   -  │ 4.92e-07 ║    │       │          ║       │            ║
#   MF ║          │                ║ -3.04324830320 ║   -  │ 3.13e-13 ║    │       │          ║       │            ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Iterations:              39                                                                                      ║
# Function evaluations:    143                                                                                     ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy Wolfe conditions at a   ║
# feasible point (to tolerances).  This may be an indication that approximate stationarity has been attained.      ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# Total Wall Time: 327.0484833717346s
# torch.norm(V @ V.T - U @ U.T) / torch.norm(U @ U.T) = 4.889914658628359e-05
# torch.trace(V.T @ A @ V) = 3.0432483031951985
# torch.trace(U.T @ A @ U) = 3.043248306041891
# sum of first d eigvals = 3.0432483060418907
# sorted eigs = tensor([ 3.0432,  0.8890, -0.4730, -0.9598, -1.8722], device='cuda:0',
#        dtype=torch.float64)

# %% [markdown]
# ## Testing

# %%
torch.testing.assert_close(
    cpu_soln.final.x,
    cuda_soln.final.x.cpu(),
    atol=1e-4,
    rtol=1e-4,
)

# %%
cpu_soln.final.x
# Out:
# tensor([[ 0.0561],
#         [ 0.1102],
#         [-0.3954],
#         [-0.8338],
#         [ 0.3648]], dtype=torch.float64)

# %%
cuda_soln.final.x.cpu()
# Out:
# tensor([[ 0.0560],
#         [ 0.1102],
#         [-0.3954],
#         [-0.8338],
#         [ 0.3648]], dtype=torch.float64)
