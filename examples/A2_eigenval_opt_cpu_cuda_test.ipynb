# %%
# %cd ..
# Out:
# /users/5/dever120/PyGRANSO

# %% [markdown]
# # Eigenvalue Optimization
#
# Eigenvalue Optimization taken from: [GRANSO](http://www.timmitchell.com/software/GRANSO/) demo example 4.

# %% [markdown]
# ## Problem Description

# %% [markdown]
# We have $M=A+BXC$,
# where the matrices $A\in R^{N,N},B\in R^{N,M}$ and $C\in R^{P,N}$ are given, $X\in R^{M,P}$ is the matrix form optimization variable.
#
# We have the nonconvex, nonsmooth, and constrained optimization problem
# $$\min_{X}\max| \mathrm{Im} (\Lambda(A+BXC))|,$$
# $$\text{s.t. }\alpha(A+BXC)+\xi \leq 0,$$
# where $\mathrm{Im}(\cdot)$ is the imaginary part of complex number, $\xi$ is the stability margin, and $\Lambda(\cdot)$ is the spectrum of a square matrix $\cdot$, and $\alpha(\cdot)$ is the spectral abscissa of a square matrix, i.e., the maximum real part of its eigenvalues.

# %% [markdown]
# ## Modules Importing
# Import all necessary modules and add PyGRANSO src folder to system path.

# %%
import time
import torch
from pygranso.pygranso import pygranso
from pygranso.pygransoStruct import pygransoStruct
import scipy.io
from torch import linalg as LA

# %% [markdown]
# ## Data Initialization
# Specify torch device, and read the data from a provided file.
#
# Use GPU for this problem. If no cuda device available, please set *device = torch.device('cpu')*

# %%
device = torch.device('cpu')

file = "/users/5/dever120/PyGRANSO/examples/data/spec_radius_opt_data.mat"
mat = scipy.io.loadmat(file)
mat_struct = mat['sys']
mat_struct = mat_struct[0,0]
# All the user-provided data (vector/matrix/tensor) must be in torch tensor format. 
# As PyTorch tensor is single precision by default, one must explicitly set `dtype=torch.double`.
# Also, please make sure the device of provided torch tensor is the same as opts.torch_device.
A = torch.from_numpy(mat_struct['A']).to(device=device, dtype=torch.double)
B = torch.from_numpy(mat_struct['B']).to(device=device, dtype=torch.double)
C = torch.from_numpy(mat_struct['C']).to(device=device, dtype=torch.double)
p = B.shape[1]
m = C.shape[0]
stability_margin = 1

# %% [markdown]
# ## Function Set-Up
#
# Encode the optimization variables, and objective and constraint functions.
#
# Note: please strictly follow the format of comb_fn, which will be used in the PyGRANSO main algortihm.

# %%
# variables and corresponding dimensions.
var_in = {"X": [p,m] }

def user_fn(X_struct,A,B,C,stability_margin):
    # user defined variable, matirx form. torch tensor
    X = X_struct.X

    # objective function
    M = A + B @ X @ C
    [D, _] = LA.eig(M)
    f = torch.max(D.imag)

    # inequality constraint, matrix form
    ci = pygransoStruct()
    ci.c1 = torch.max(D.real) + stability_margin

    # equality constraint 
    ce = None
    
    return [f, ci, ce]

comb_fn = lambda X_struct : user_fn(X_struct, A, B, C, stability_margin)

# %% [markdown]
# ## User Options
# Specify user-defined options for PyGRANSO

# %%
opts = pygransoStruct()
opts.torch_device = device
opts.maxit = 1000
opts.x0 = torch.zeros(p * m, 1).to(device=device, dtype=torch.double)
# print for every 10 iterations. default: 1
opts.print_frequency = 10

# %% [markdown]
# ## Main Algorithm

# %%
start = time.time()
cpu_soln = pygranso(var_spec=var_in, combined_fn=comb_fn, user_opts=opts)
end = time.time()
print("Total Wall Time: {}s".format(end - start))
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                                             ║
# Version 1.2.0                                                                                                    ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang                                  ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                                          ║
#  # of variables                     :
-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  880 ║ 0.071790 │  0.75475594075 ║  10.5132894897 ║ 9.00e-06 │   -  ║ S  │     6 │ 0.031250 ║     4 │ 3.06e-05   ║
#  890 ║ 0.071790 │  0.75465003757 ║  10.5119397256 ║ 0.000000 │   -  ║ S  │     2 │ 2.000000 ║     2 │ 3.25e-05   ║
#  900 ║ 0.071790 │  0.75455408501 ║  10.5106031491 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     4 │ 6.05e-05   ║
#  910 ║ 0.071790 │  0.75449025968 ║  10.5097140905 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     2 │ 1.06e-05   ║
# Polishing not needed - no active set detected at optimal point
#  920 ║ 0.071790 │  0.75439336703 ║  10.5083644190 ║ 0.000000 │   -  ║ S  │     7 │ 0.703125 ║     3 │ 3.13e-05   ║
#  930 ║ 0.071790 │  0.75433505822 ║  10.5075373798 ║ 1.06e-06 │   -  ║ S  │     4 │ 3.000000 ║     1 │ 2.78e-04   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  940 ║ 0.071790 │  0.75429088882 ║  10.5069369431 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     2 │ 4.18e-05   ║
# Polishing not needed - no active set detected at optimal point
#  950 ║ 0.071790 │  0.75427005666 ║  10.5066467602 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     6 │ 1.82e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  960 ║ 0.071790 │  0.75421903803 ║  10.5059360934 ║ 0.000000 │   -  ║ S  │     4 │ 1.250000 ║     1 │ 0.002032   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  970 ║ 0.071790 │  0.75418193765 ║  10.5054193017 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     2 │ 2.04e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  980 ║ 0.071790 │  0.75406144736 ║  10.5036929856 ║ 3.44e-06 │   -  ║ S  │     3 │ 1.500000 ║     1 │ 4.06e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  990 ║ 0.038152 │  0.40068205502 ║  10.5022427381 ║ 4.43e-08 │   -  ║ S  │     1 │ 1.000000 ║     2 │ 4.26e-05   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
# 1000 ║ 0.038152 │  0.40065353893 ║  10.5014964658 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 6.16e-06   ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                                   ║
# Optimization results:                                                                                            ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#    F ║          │                ║  10.5014964658 ║ 0.000000 │   -  ║    │       │          ║       │            ║
#    B ║          │                ║  10.5014964658 ║ 0.000000 │   -  ║    │       │          ║       │            ║
#   MF ║          │                ║  10.5014964658 ║ 0.000000 │   -  ║    │       │          ║       │            ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Iterations:              1000                                                                                    ║
# Function evaluations:    3953                                                                                    ║
# PyGRANSO termination code: 4 --- max iterations reached.                                                         ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# Total Wall Time: 262.076096534729s

# %% [markdown]
# ## CUDA Computation

# %%
device = torch.device('cuda')

file = "/users/5/dever120/PyGRANSO/examples/data/spec_radius_opt_data.mat"
mat = scipy.io.loadmat(file)
mat_struct = mat['sys']
mat_struct = mat_struct[0,0]
# All the user-provided data (vector/matrix/tensor) must be in torch tensor format. 
# As PyTorch tensor is single precision by default, one must explicitly set `dtype=torch.double`.
# Also, please make sure the device of provided torch tensor is the same as opts.torch_device.
A = torch.from_numpy(mat_struct['A']).to(device=device, dtype=torch.double)
B = torch.from_numpy(mat_struct['B']).to(device=device, dtype=torch.double)
C = torch.from_numpy(mat_struct['C']).to(device=device, dtype=torch.double)
p = B.shape[1]
m = C.shape[0]
stability_margin = 1

# %%
# variables and corresponding dimensions.
var_in = {"X": [p,m] }

def user_fn(X_struct,A,B,C,stability_margin):
    # user defined variable, matirx form. torch tensor
    X = X_struct.X

    # objective function
    M = A + B @ X @ C
    [D, _] = LA.eig(M)
    f = torch.max(D.imag)

    # inequality constraint, matrix form
    ci = pygransoStruct()
    ci.c1 = torch.max(D.real) + stability_margin

    # equality constraint 
    ce = None
    
    return [f, ci, ce]

comb_fn = lambda X_struct : user_fn(X_struct, A, B, C, stability_margin)

# %%
opts = pygransoStruct()
opts.torch_device = device
opts.maxit = 1000
opts.x0 = torch.zeros(p * m, 1).to(device=device, dtype=torch.double)
# print for every 10 iterations. default: 1
opts.print_frequency = 10

# %%
start = time.time()
cuda_soln = pygranso(var_spec=var_in, combined_fn=comb_fn, user_opts=opts)
end = time.time()
print("Total Wall Time: {}s".format(end - start))
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                                             ║
# Version 1.2.0                                                                                                    ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang                                  ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                                          ║
#  # of variables                     :   200                                                                      ║
#  # of inequality constraints        :     1                                                                      ║
#  # of equality constraints          :     0                                                                      ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#    0 ║ 1.000000 │  16.2063030241 ║  13.7635444107 ║ 2.442759 │   -  ║ -  │     1 │ 0.000000 ║     1 │ 28.28938   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   10 ║ 1.000000 │  14.3596190048 ║  12.9268516442 ║ 1.432767 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 0.035504   ║
# Polishing not needed - no active set detected at optimal point
#   20 ║ 1.000000 │  13.7030947530 ║  12.6546385093 ║ 1.048456 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 0.039570   ║
# Polishing not needed - no active set detected at optimal point
#   30 ║ 1.000000 │  12.8619992390 ║  12.2684493972 ║ 0.593550 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.048313   ║
#   40 ║ 1.000000 │  12.6580073473 ║  12.1060381722 ║ 0.551969 │   -  ║ S  │     8 │ 0.007812 ║     1 │ 0.035025   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   50 ║ 0.900000 │  11.1959320070 ║  11.9651062875 ║ 0.427336 │   -  ║ S  │     7 │ 0.015625 ║     1 │ 0.019149   ║
#   60 ║ 0.900000 │  11.0019058741 ║  11.8891094886 ║ 0.301707 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.024572   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   70 ║ 0.900000 │  10.7402495972 ║  11.7776489857 ║ 0.140366 │   -  ║ S  │     5 │ 0.062500 ║     1 │ 0.023790   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#   80 ║ 0.900000 │  10.6505495789 ║  11.7178000939 ║ 0.104529 │   -  ║ S  │     9 │ 0.003906 ║     1 │ 0.027543   ║
#   90 ║ 0.900000 │  10.5550238604 ║  11.6617452588 ║ 0.059453 │   -  ║ S  │     8 │ 0.007812 ║     1 │ 0.017797   ║
# Polishing not needed - no active set detected at optimal point
#  100 ║ 0.900000 │  10.5174843646 ║  11.6350044200 ║ 0.045980 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.008861   ║
#  110 ║ 0.656100 │  7.60724730848 ║  11.5857444155 ║ 0.005840 │   -  ║ S  │     5 │ 0.062500 ║     1 │ 0.021166   ║
#  120 ║ 0.656100 │  7.53940922695 ║  11.4748127369 ║ 0.010785 │   -  ║ S  │     3 │ 0.250000 ║     1 │ 0.018523   ║
#  130 ║ 0.656100 │  7.49894013674 ║  11.4295688717 ║ 0.000000 │   -  ║ S  │    12 │ 4.88e-04 ║     2 │ 0.035130   ║
#  140 ║ 0.656100 │  7.43816812759 ║  11.3310879220 ║ 0.003841 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.019502   ║
#  150 ║ 0.656100 │  7.40075182836 ║  11.2799143855 ║ 0.000000 │   -  ║ S  │     8 │ 0.007812 ║     1 │ 0.055410   ║
#  160 ║ 0.656100 │  7.37427900944 ║  11.2395656294 ║ 0.000000 │   -  ║ S  │     8 │ 0.007812 ║     1 │ 0.071111   ║
# Polishing not needed - no active set detected at optimal point
#  170 ║ 0.656100 │  7.34760395819 ║  11.1989086392 ║ 0.000000 │   -  ║ S  │     5 │ 0.062500 ║     1 │ 0.006268   ║
#  180 ║ 0.656100 │  7.32645781229 ║  11.1666785738 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 0.008504   ║
#  190 ║ 0.656100 │  7.30146061727 ║  11.1285789015 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.007539   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  200 ║ 0.656100 │  7.28574303754 ║  11.1046228281 ║ 0.000000 │   -  ║ S  │     6 │ 0.031250 ║     1 │ 0.077012   ║
# Polishing not needed - no active set detected at optimal point
#  210 ║ 0.656100 │  7.26658237264 ║  11.0744591358 ║ 6.30e-04 │   -  ║ S  │     7 │ 0.015625 ║     1 │ 0.026257   ║
#  220 ║ 0.656100 │  7.24025255179 ║  11.0352881448 ║ 0.000000 │   -  ║ S  │     5 │ 0.062500 ║     1 │ 0.009434   ║
#  230 ║ 0.656100 │  7.21149110206 ║  10.9914511539 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.011358   ║
# Polishing not needed - no active set detected at optimal point
#  240 ║ 0.478297 │  5.23982863188 ║  10.9481842094 ║ 0.003346 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 0.011053   ║
# Polishing not needed - no active set detected at optimal point
#  250 ║ 0.478297 │  5.22203861512 ║  10.9179854921 ║ 0.000000 │   -  ║ S  │     7 │ 0.015625 ║     1 │ 0.002486   ║
# Polishing not needed - no active set detected at optimal point
#  260 ║ 0.478297 │  5.21527652739 ║  10.9025771051 ║ 6.08e-04 │   -  ║ S  │     6 │ 0.031250 ║     1 │ 0.014530   ║
#  270 ║ 0.478297 │  5.20503092174 ║  10.8824266303 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     1 │ 0.003559   ║
# Polishing not needed - no active set detected at optimal point
#  280 ║ 0.478297 │  5.19327673012 ║  10.8568524296 ║ 4.78e-04 │   -  ║ S  │     6 │ 0.031250 ║     1 │ 0.032259   ║
# Polishing not needed - no active set detected at optimal point
#  290 ║ 0.478297 │  5.18314592759 ║  10.8351969610 ║ 7.05e-04 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 0.003727   ║
#  300 ║ 0.478297 │  5.17864151614 ║  10.8265338020 ║ 3.44e-04 │   -  ║ S  │     8 │ 0.007812 ║     2 │ 0.001577   ║
# Polishing not needed - no active set detected at optimal point
#  310 ║ 0.478297 │  5.17038369999 ║  10.8099878966 ║ 0.000000 │   -  ║ S  │     6 │ 0.031250 ║     1 │ 0.005335   ║
#  320 ║ 0.478297 │  5.16341984769 ║  10.7954282114 ║ 0.000000 │   -  ║ S  │     7 │ 0.015625 ║     2 │ 0.004435   ║
# Polishing not needed - no active set detected at optimal point
#  330 ║ 0.478297 │  5.15428252487 ║  10.7763243393 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     1 │ 0.001524   ║
# Polishing not needed - no active set detected at optimal point
#  340 ║ 0.478297 │  5.14495296194 ║  10.7568185408 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     1 │ 0.002365   ║
#  350 ║ 0.478297 │  5.14089334844 ║  10.7483308975 ║ 0.000000 │   -  ║ S  │     8 │ 0.023438 ║     1 │ 0.011894   ║
# Polishing not needed - no active set detected at optimal point
#  360 ║ 0.478297 │  5.13688139250 ║  10.7399428943 ║ 0.000000 │   -  ║ S  │     9 │ 0.003906 ║     1 │ 0.062716   ║
#  370 ║ 0.478297 │  5.13327735104 ║  10.7322121009 ║ 9.36e-05 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.003150   ║
# Polishing not needed - no active set detected at optimal point
#  380 ║ 0.478297 │  5.12943407334 ║  10.7233548650 ║ 4.87e-04 │   -  ║ S  │     7 │ 0.015625 ║     1 │ 0.003154   ║
#  390 ║ 0.478297 │  5.12574938485 ║  10.7166686317 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 0.001584   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  400 ║ 0.478297 │  5.12356584625 ║  10.7121033949 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 0.001888   ║
#  410 ║ 0.478297 │  5.12032676466 ║  10.7053312799 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.001936   ║
#  420 ║ 0.478297 │  5.11907937816 ║  10.7027233046 ║ 0.000000 │   -  ║ S  │     7 │ 0.015625 ║     1 │ 0.011589   ║
#  430 ║ 0.478297 │  5.11689844059 ║  10.6981635059 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 3.37e-04   ║
#  440 ║ 0.478297 │  5.11338580805 ║  10.6908039607 ║ 7.42e-06 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 9.78e-04   ║
#  450 ║ 0.478297 │  5.10984920326 ║  10.6834253018 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 0.001688   ║
#  460 ║ 0.478297 │  5.10577611435 ║  10.6732734168 ║ 7.83e-04 │   -  ║ S  │     6 │ 0.031250 ║     2 │ 0.001334   ║
#  470 ║ 0.478297 │  5.10215776325 ║  10.6673444115 ║ 0.000000 │   -  ║ S  │     9 │ 0.027344 ║     2 │ 3.68e-04   ║
#  480 ║ 0.478297 │  5.09816797518 ║  10.6590027558 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 0.002078   ║
#  490 ║ 0.478297 │  5.09655953055 ║  10.6556398976 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     2 │ 3.70e-04   ║
# Polishing not needed - no active set detected at optimal point
#  500 ║ 0.478297 │  5.09500850456 ║  10.6523970876 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 3.74e-04   ║
#  510 ║ 0.478297 │  5.09286193025 ║  10.6479091339 ║ 0.000000 │   -  ║ S  │     6 │ 0.156250 ║     1 │ 0.018977   ║
#  520 ║ 0.478297 │  5.09080719640 ║  10.6436131959 ║ 0.000000 │   -  ║ S  │     8 │ 0.007812 ║     2 │ 9.32e-04   ║
#  530 ║ 0.478297 │  5.08893700186 ║  10.6397030837 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 4.40e-04   ║
#  540 ║ 0.478297 │  5.08548394068 ║  10.6324835906 ║ 0.000000 │   -  ║ S  │     5 │ 0.062500 ║     1 │ 0.004376   ║
# Polishing not needed - no active set detected at optimal point
#  550 ║ 0.478297 │  5.08049430757 ║  10.6220515073 ║ 0.000000 │   -  ║ S  │    11 │ 0.014648 ║     3 │ 9.36e-04   ║
#  560 ║ 0.478297 │  5.07672107779 ║  10.6141626211 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 8.46e-04   ║
#  570 ║ 0.478297 │  5.07440589153 ║  10.6093221418 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 6.62e-04   ║
# Polishing not needed - no active set detected at optimal point
#  580 ║ 0.228768 │  2.42639219375 ║  10.6063478896 ║ 0.000000 │   -  ║ S  │     5 │ 0.062500 ║     1 │ 0.001180   ║
#  590 ║ 0.228768 │  2.42579176501 ║  10.6037232702 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     2 │ 1.05e-04   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  600 ║ 0.228768 │  2.42529837082 ║  10.6015665246 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     2 │ 8.45e-05   ║
# Polishing not needed - no active set detected at optimal point
#  610 ║ 0.228768 │  2.42454335838 ║  10.5982661824 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     1 │ 7.05e-04   ║
# Polishing not needed - no active set detected at optimal point
#  620 ║ 0.228768 │  2.42311488515 ║  10.5919681527 ║ 1.23e-05 │   -  ║ S  │     6 │ 0.156250 ║     2 │ 8.31e-05   ║
#  630 ║ 0.228768 │  2.42195761373 ║  10.5869632664 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     1 │ 5.98e-04   ║
#  640 ║ 0.228768 │  2.42034616138 ║  10.5799192179 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 5.44e-04   ║
#  650 ║ 0.228768 │  2.41959875335 ║  10.5766521164 ║ 0.000000 │   -  ║ S  │     4 │ 0.375000 ║     1 │ 2.04e-04   ║
#  660 ║ 0.228768 │  2.41905422346 ║  10.5742558508 ║ 3.66e-06 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 1.05e-04   ║
# Polishing not needed - no active set detected at optimal point
#  670 ║ 0.228768 │  2.41744917602 ║  10.5668132878 ║ 1.01e-04 │   -  ║ S  │     4 │ 0.125000 ║     1 │ 2.40e-04   ║
#  680 ║ 0.228768 │  2.41534060773 ║  10.5580387307 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 4.64e-04   ║
# Polishing not needed - no active set detected at optimal point
#  690 ║ 0.228768 │  2.41320933062 ║  10.5487123897 ║ 2.29e-06 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 5.29e-04   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#  700 ║ 0.228768 │  2.41245426482 ║  10.5454218268 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 3.11e-04   ║
#  710 ║ 0.228768 │  2.41115156152 ║  10.5397273952 ║ 0.000000 │   -  ║ S  │     2 │ 2.000000 ║     1 │ 4.07e-04   ║
# Polishing not needed - no active set detected at optimal point
#  720 ║ 0.228768 │  2.40986302669 ║  10.5340948974 ║ 0.000000 │   -  ║ S  │     9 │ 0.003906 ║     2 │ 0.006842   ║
#  730 ║ 0.228768 │  2.40888916795 ║  10.5298059832 ║ 7.31e-06 │   -  ║ S  │     7 │ 0.296875 ║     2 │ 1.34e-04   ║
#  740 ║ 0.228768 │  2.40770931345 ║  10.5246713542 ║ 2.09e-06 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 1.90e-04   ║
#  750 ║ 0.166772 │  1.75434027171 ║  10.5190948756 ║ 5.17e-05 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 2.68e-04   ║
#  760 ║ 0.166772 │  1.75374494538 ║  10.5158352110 ║ 0.000000 │   -  ║ S  │     4 │ 0.875000 ║     1 │ 0.003238   ║
#  770 ║ 0.166772 │  1.75332001049 ║  10.5132872092 ║ 0.000000 │   -  ║ S  │     3 │ 4.000000 ║     1 │ 9.00e-05   ║
#  780 ║ 0.166772 │  1.75292500796 ║  10.5109186884 ║ 0.000000 │   -  ║ S  │     2 │ 2.000000 ║     1 │ 7.95e-05   ║
#  790 ║ 0.166772 │  1.75243529392 ║  10.5079822567 ║ 0.000000 │   -  ║ S  │     3 │ 0.250000 ║     3 │ 1.26e-04   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  800 ║ 0.166772 │  1.75194244162 ║  10.5050212267 ║ 9.64e-07 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 4.70e-05   ║
#  810 ║ 0.166772 │  1.75145397103 ║  10.5020980318 ║ 0.000000 │   -  ║ S  │     7 │ 0.015625 ║     3 │ 2.61e-04   ║
#  820 ║ 0.166772 │  1.75113954872 ║  10.5001566068 ║ 9.35e-06 │   -  ║ S  │     7 │ 0.078125 ║     4 │ 5.34e-05   ║
# Polishing not needed - no active set detected at optimal point
#  830 ║ 0.109419 │  1.14837085256 ║  10.4951696380 ║ 0.000000 │   -  ║ S  │     3 │ 0.750000 ║     1 │ 0.001145   ║
#  840 ║ 0.109419 │  1.14821939647 ║  10.4937854534 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     2 │ 1.22e-04   ║
#  850 ║ 0.109419 │  1.14793160001 ║  10.4911552293 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     2 │ 3.30e-05   ║
#  860 ║ 0.109419 │  1.14757392453 ║  10.4878863682 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     2 │ 6.05e-05   ║
#  870 ║ 0.109419 │  1.14719647627 ║  10.4844368000 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 0.001136   ║
#  880 ║ 0.109419 │  1.14695334862 ║  10.4822148123 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 1.07e-04   ║
#  890 ║ 0.109419 │  1.14670702876 ║  10.4797511352 ║ 2.33e-05 │   -  ║ S  │     1 │ 1.000000 ║     1 │ 8.94e-04   ║
#  900 ║ 0.109419 │  1.14632982529 ║  10.4765163194 ║ 0.000000 │   -  ║ S  │     4 │ 0.375000 ║     2 │ 1.69e-04   ║
#  910 ║ 0.109419 │  1.14570553665 ║  10.4708108322 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     4 │ 9.62e-05   ║
#  920 ║ 0.109419 │  1.14549434530 ║  10.4688807162 ║ 0.000000 │   -  ║ S  │     4 │ 3.000000 ║     1 │ 1.15e-04   ║
#  930 ║ 0.109419 │  1.14530540276 ║  10.4671539360 ║ 0.000000 │   -  ║ S  │     4 │ 0.125000 ║     5 │ 5.80e-06   ║
#  940 ║ 0.109419 │  1.14527374371 ║  10.4668645982 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║    10 │ 2.35e-05   ║
#  950 ║ 0.109419 │  1.14516494377 ║  10.4658702558 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     6 │ 8.09e-06   ║
#  960 ║ 0.109419 │  1.14508798323 ║  10.4651668994 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     4 │ 8.82e-06   ║
#  970 ║ 0.109419 │  1.14500239238 ║  10.4643846692 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     6 │ 1.04e-05   ║
#  980 ║ 0.109419 │  1.14482895762 ║  10.4627996174 ║ 0.000000 │   -  ║ S  │     2 │ 0.500000 ║     3 │ 1.89e-05   ║
#  990 ║ 0.109419 │  1.14475987080 ║  10.4621682204 ║ 0.000000 │   -  ║ S  │     1 │ 1.000000 ║     8 │ 1.40e-05   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║   Ineq   │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
# 1000 ║ 0.109419 │  1.14472882121 ║  10.4618834839 ║ 1.06e-07 │   -  ║ S  │     1 │ 1.000000 ║     3 │ 2.71e-05   ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                                   ║
# Optimization results:                                                                                            ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#    F ║          │                ║  10.4618834839 ║ 1.06e-07 │   -  ║    │       │          ║       │            ║
#    B ║          │                ║  10.4618834839 ║ 1.06e-07 │   -  ║    │       │          ║       │            ║
#   MF ║          │                ║  10.4619503514 ║ 0.000000 │   -  ║    │       │          ║       │            ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Iterations:              1000                                                                                    ║
# Function evaluations:    4053                                                                                    ║
# PyGRANSO termination code: 4 --- max iterations reached.                                                         ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# Total Wall Time: 11053.454025745392s

# %% [markdown]
# ## Testing

# %%
torch.testing.assert_close(
    cpu_soln.final.x,
    cuda_soln.final.x.cpu(),
    atol=1e-2,
    rtol=1e-2,
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 torch.testing.assert_close(
#       2     cpu_soln.final.x,
#       3     cuda_soln.final.x.cpu(),
#       4     atol=1e-2,
#       5     rtol=1e-2,
#       6 )
#
# File ~/PyGRANSO/.venv/lib/python3.13/site-packages/torch/testing/_comparison.py:1587, in assert_close(actual, expected, allow_subclasses, rtol, atol, equal_nan, check_device, check_dtype, check_layout, check_stride, msg)
#    1565 error_metas = not_close_error_metas(
#    1566     actual,
#    1567     expected,
#    (...)   1582     msg=msg,
#    1583 )
#    1585 if error_metas:
#    1586     # TODO: compose all metas into one AssertionError
# -> 1587     raise error_metas[0].to_error(msg)
#
# AssertionError: Tensor-likes are not close!
#
# Mismatched elements: 35 / 200 (17.5%)
# Greatest absolute difference: 0.024607874336102162 at index (103, 0) (up to 0.01 allowed)
# Greatest relative difference: 58.06304384630274 at index (5, 0) (up to 0.01 allowed)

# %%
cpu_soln.final.x[:10]
# Out:
# tensor([[-0.0297],
#         [ 0.0087],
#         [-0.0107],
#         [-0.0038],
#         [-0.0236],
#         [ 0.0134],
#         [ 0.0067],
#         [-0.0208],
#         [-0.0008],
#         [-0.0100]], dtype=torch.float64)

# %%
cuda_soln.final.x.cpu()[:10]
# Out:
# tensor([[-0.0285],
#         [-0.0028],
#         [-0.0071],
#         [-0.0262],
#         [-0.0141],
#         [-0.0002],
#         [-0.0021],
#         [-0.0123],
#         [ 0.0023],
#         [-0.0078]], dtype=torch.float64)
