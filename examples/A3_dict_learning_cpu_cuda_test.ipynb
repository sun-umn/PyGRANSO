# %%
# %cd ..
# Out:
# /users/5/dever120/PyGRANSO

# %% [markdown]
# # Dictionary Learning
#
# Solve orthogonal dictionary learning problem taken from: Yu Bai, Qijia Jiang, and Ju Sun.
# ["Subgradient descent learns orthogonal dictionaries."](https://arxiv.org/abs/1810.10702) arXiv preprint arXiv:1810.10702 (2018).

# %% [markdown]
# ## Problem Description

# %% [markdown]
# Given data $\{y_i \}_{i \in[m]}$ generated as $y_i = A x_i$, where $A \in R^{n \times n}$ is a fixed unknown orthogonal matrix and each $x_i \in R^n$ is an iid Bernoulli-Gaussian random vector with parameter $\theta \in (0,1)$, recover $A$.
#
# Write $Y \doteq [y_1,...,y_m]$ and $X \doteq [x_1,...,x_m]$. To find the column of $A$, one can perform the following optimization:
#
# $$\min_{q \in R^n} f(q) \doteq \frac{1}{m} ||q^T Y||_{1} = \frac{1}{m} \sum_{i=1}^m |q^T y_i|,$$
# $$\text{s.t.} ||q||_2 = 1$$
#
# This problem is nonconvex due to the constraint and nonsmooth due to the objective.
#
# Based on the above statistical model, $q^T Y = q^T A X$ has the highest sparsity when $q$ is a column of $A$ (up to sign) so that $q^T A$ is 1-sparse.

# %% [markdown]
# ## Modules Importing
# Import all necessary modules and add PyGRANSO src folder to system path.

# %%
import time
import numpy as np
import torch
import numpy.linalg as la
from scipy.stats import norm
from pygranso.pygranso import pygranso
from pygranso.pygransoStruct import pygransoStruct

# %% [markdown]
# ## Data Initialization
# Specify torch device, and generate data
#
# Use GPU for this problem. If no cuda device available, please set *device = torch.device('cpu')*

# %%
from numpy import inf
import osqp

# %%
osqp.algebras_available()
# Out:
# ['cuda', 'builtin']

# %%
device = torch.device('cpu')
n = 30

np.random.seed(1)
m = 10*n**2   # sample complexity
theta = 0.3   # sparsity level
Y = norm.ppf(np.random.rand(n,m)) * (norm.ppf(np.random.rand(n,m)) <= theta)  # Bernoulli-Gaussian model
# All the user-provided data (vector/matrix/tensor) must be in torch tensor format. 
# As PyTorch tensor is single precision by default, one must explicitly set `dtype=torch.double`.
# Also, please make sure the device of provided torch tensor is the same as opts.torch_device.
Y = torch.from_numpy(Y).to(device=device, dtype=torch.double)

# %% [markdown]
# ## Function Set-Up
#
# Encode the optimization variables, and objective and constraint functions.
#
# Note: please strictly follow the format of comb_fn, which will be used in the PyGRANSO main algortihm.

# %%
# variables and corresponding dimensions.
var_in = {"q": [n,1]}


def user_fn(X_struct,Y):
    q = X_struct.q
    
    # objective function
    qtY = q.T @ Y
    f = 1/m * torch.norm(qtY, p = 1)

    # inequality constraint, matrix form
    ci = None

    # equality constraint 
    ce = pygransoStruct()
    ce.c1 = q.T @ q - 1

    return [f,ci,ce]

comb_fn = lambda X_struct : user_fn(X_struct,Y)

# %% [markdown]
# ## User Options
# Specify user-defined options for PyGRANSO

# %%
opts = pygransoStruct()
opts.torch_device = device
opts.maxit = 500
np.random.seed(1)
x0 = norm.ppf(np.random.rand(n,1))
x0 /= la.norm(x0,2)
opts.x0 = torch.from_numpy(x0).to(device=device, dtype=torch.double)

opts.print_frequency = 1

# %% [markdown]
# ## Main Algorithm

# %%
start = time.time()
cpu_soln = pygranso(var_spec = var_in,combined_fn = comb_fn,user_opts = opts)
end = time.time()
print("Total Wall Time: {}s".format(end - start))
print(max(abs(cpu_soln.final.x))) # should be close to 1
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                                             ║
# Version 1.2.0                                                                                                    ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang                                  ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                                          ║
#  # of variables                     :   30                                                                       ║
#  # of inequality constraints        :    0                                                                       ║
#  # of equality constraints          :    1                                                                       ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#    0 ║ 1.000000 │  0.61751624522 ║  0.61751624522 ║   -  │ 2.22e-16 ║ -  │     1 │ 0.000000 ║     1 │ 0.054664   ║
# Polishing not needed - no active set detected at optimal point
#    1 ║ 1.000000 │  0.61702307765 ║  0.61627605090 ║   -  │ 7.47e-04 ║ S  │     2 │ 0.500000 ║     1 │ 0.054092   ║
# Polishing not needed - no active set detected at optimal point
#    2 ║ 1.000000 │  0.61551810339 ║  0.61506161805 ║   -  │ 4.56e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.020707   ║
# Polishing not needed - no active set detected at optimal point
#    3 ║ 1.000000 │  0.61441100190 ║  0.61398119805 ║   -  │ 4.30e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.020540   ║
# Polishing not needed - no active set detected at optimal point
#    4 ║ 1.000000 │  0.61332843662 ║  0.61287992865 ║   -  │ 4.49e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.021556   ║
# Polishing not needed - no active set detected at optimal point
#    5 ║ 1.000000 │  0.61218884017 ║  0.61172727338 ║   -  │ 4.62e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.021850   ║
# Polishing not needed - no active set detected at optimal point
#    6 ║ 1.000000 │  0.61103777776 ║  0.61055947773 ║   -  │ 4.78e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.021947   ║
# Polishing not needed - no active set detected at optimal point
#    7 ║ 1.000000 │  0.60985285743 ║  0.60934998461 ║   -  │ 5.03e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.022969   ║
# Polishing not needed - no active set detected at optimal point
#    8 ║ 1.000000 │  0.60856276916 ║  0.60804023356 ║   -  │ 5.23e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.024237   ║
# Polishing not needed - no active set detected at optimal point
#    9 ║ 1.000000 │  0.60723803355 ║  0.60661959024 ║   -  │ 6.18e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.025115   ║
# Polishing not needed - no active set detected at optimal point
#   10 ║ 1.000000 │  0.60573380055 ║  0.60513582468 ║   -  │ 5.98e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.024968   ║
# Polishing not needed - no active set detected at optimal point
#   11 ║ 1.000000 │  0.60424293887 ║  0.60357926042 ║   -  │ 6.64e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.025398   ║
# Polishing not needed - no active set detected at optimal point
#   12 ║ 1.000000 │  0.60264174084 ║  0.60205401901 ║   -  │ 5.88e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.025404   ║
# Polishing not needed - no active set detected at optimal point
#   13 ║ 1.000000 │  0.60112158221 ║  0.60042789670 ║   -  │ 6.94e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.026728   ║
# Polishing not needed - no active set detected at optimal point
#   14 ║ 1.000000 │  0.59939832379 ║  0.59867187957 ║   -  │ 7.26e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.027875   ║
# Polishing not needed - no active set detected at optimal point
#   15 ║ 1.000000 │  0.59755471247 ║  0.59678393730 ║   -  │ 7.71e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.029039   ║
# Polishing not needed - no active set detected at optimal point
#   16 ║ 1.000000 │  0.59557678818 ║  0.59470382814 ║   -  │ 8.73e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.031359   ║
# Polishing not needed - no active set detected at optimal point
#   17 ║ 1.000000 │  0.59331076681 ║  0.59230323990 ║   -  │ 0.001008 ║ S  │     1 │ 1.000000 ║     1 │ 0.034111   ║
# Polishing not needed - no active set detected at optimal point
#   18 ║ 1.000000 │  0.59079804571 ║  0.58960272795 ║   -  │ 0.001195 ║ S  │     1 │ 1.000000 ║     1 │ 0.035771   ║
# Polishing not needed - no active set detected at optimal point
#   19 ║ 1.000000 │  0.58783565381 ║  0.58663477560 ║   -  │ 0.001201 ║ S  │     1 │ 1.000000 ║     1 │ 0.037719   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   20 ║ 1.000000 │  0.58456516016 ║  0.58301955756 ║   -  │ 0.001546 ║ S  │     1 │ 1.000000 ║     1 │ 0.043517   ║
# Polishing not needed - no active set detected at optimal point
#   21 ║ 1.000000 │  0.58048791392 ║  0.57857406344 ║   -  │ 0.001914 ║ S  │     1 │ 1.000000 ║     1 │ 0.047689   ║
# Polishing not needed - no active set detected at optimal point
#   22 ║ 1.000000 │  0.57541847946 ║  0.57319663659 ║   -  │ 0.002222 ║ S  │     1 │ 1.000000 ║     1 │ 0.052957   ║
# Polishing not needed - no active set detected at optimal point
#   23 ║ 1.000000 │  0.56957727394 ║  0.56654718007 ║   -  │ 0.003030 ║ S  │     1 │ 1.000000 ║     1 │ 0.057616   ║
# Polishing not needed - no active set detected at optimal point
#   24 ║ 1.000000 │  0.56218615035 ║  0.55925621563 ║   -  │ 0.002930 ║ S  │     1 │ 1.000000 ║     1 │ 0.057340   ║
# Polishing not needed - no active set detected at optimal point
#   25 ║ 1.000000 │  0.55445266784 ║  0.55098297350 ║   -  │ 0.003470 ║ S  │     1 │ 1.000000 ║     1 │ 0.064129   ║
# Polishing not needed - no active set detected at optimal point
#   26 ║ 1.000000 │  0.54521324651 ║  0.54083272102 ║   -  │ 0.004381 ║ S  │     1 │ 1.000000 ║     1 │ 0.071545   ║
# Polishing not needed - no active set detected at optimal point
#   27 ║ 1.000000 │  0.53417344978 ║  0.52883390877 ║   -  │ 0.005340 ║ S  │     1 │ 1.000000 ║     1 │ 0.077678   ║
# Polishing not needed - no active set detected at optimal point
#   28 ║ 1.000000 │  0.52105789534 ║  0.51493137391 ║   -  │ 0.006127 ║ S  │     1 │ 1.000000 ║     1 │ 0.081297   ║
# Polishing not needed - no active set detected at optimal point
#   29 ║ 1.000000 │  0.50661423187 ║  0.49938678733 ║   -  │ 0.007227 ║ S  │     1 │ 1.000000 ║     1 │ 0.084691   ║
# Polishing not needed - no active set detected at optimal point
#   30 ║ 1.000000 │  0.50113197499 ║  0.49475409554 ║   -  │ 0.006378 ║ S  │     3 │ 0.250000 ║     1 │ 0.121253   ║
# Polishing not needed - no active set detected at optimal point
#   31 ║ 1.000000 │  0.49885155695 ║  0.49807194127 ║   -  │ 7.80e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.085292   ║
# Polishing not needed - no active set detected at optimal point
#   32 ║ 1.000000 │  0.49567824251 ║  0.49514780922 ║   -  │ 5.30e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.043007   ║
# Polishing not needed - no active set detected at optimal point
#   33 ║ 1.000000 │  0.49475832555 ║  0.49427196756 ║   -  │ 4.86e-04 ║ S  │     3 │ 0.250000 ║     1 │ 0.033135   ║
# Polishing not needed - no active set detected at optimal point
#   34 ║ 1.000000 │  0.49461850125 ║  0.49417459153 ║   -  │ 4.44e-04 ║ S  │     2 │ 0.500000 ║     1 │ 0.075451   ║
# Polishing not needed - no active set detected at optimal point
#   35 ║ 1.000000 │  0.49446141873 ║  0.49408909193 ║   -  │ 3.72e-04 ║ S  │     2 │ 0.500000 ║     1 │ 0.057787   ║
# Polishing not needed - no active set detected at optimal point
#   36 ║ 1.000000 │  0.49396867492 ║  0.49369514842 ║   -  │ 2.74e-04 ║ S  │     2 │ 0.500000 ║     1 │ 0.067831   ║
# Polishing not needed - no active set detected at optimal point
#   37 ║ 1.000000 │  0.49341655337 ║  0.49316518216 ║   -  │ 2.51e-04 ║ S  │     3 │ 0.250000 ║     1 │ 0.047320   ║
# Polishing not needed - no active set detected at optimal point
#   38 ║ 1.000000 │  0.49315094811 ║  0.49291923533 ║   -  │ 2.32e-04 ║ S  │     4 │ 0.125000 ║     1 │ 0.026022   ║
# Polishing not needed - no active set detected at optimal point
#   39 ║ 1.000000 │  0.49291418878 ║  0.49272561853 ║   -  │ 1.89e-04 ║ S  │     3 │ 0.250000 ║     1 │ 0.060973   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   40 ║ 1.000000 │  0.49278124194 ║  0.49260444460 ║   -  │ 1.77e-04 ║ S  │     4 │ 0.125000 ║     1 │ 0.037304   ║
# Polishing not needed - no active set detected at optimal point
#   41 ║ 1.000000 │  0.49269738504 ║  0.49253958880 ║   -  │ 1.58e-04 ║ S  │     4 │ 0.125000 ║     1 │ 0.036178   ║
# Polishing not needed - no active set detected at optimal point
#   42 ║ 1.000000 │  0.49254878364 ║  0.49240783666 ║   -  │ 1.41e-04 ║ S  │     4 │ 0.125000 ║     1 │ 0.034184   ║
# Polishing not needed - no active set detected at optimal point
#   43 ║ 1.000000 │  0.49250977220 ║  0.49237510184 ║   -  │ 1.35e-04 ║ S  │     5 │ 0.062500 ║     1 │ 0.044762   ║
# Polishing not needed - no active set detected at optimal point
#   44 ║ 1.000000 │  0.49244706798 ║  0.49232667468 ║   -  │ 1.20e-04 ║ S  │     4 │ 0.125000 ║     1 │ 0.052491   ║
# Polishing not needed - no active set detected at optimal point
#   45 ║ 1.000000 │  0.49241479031 ║  0.49230000060 ║   -  │ 1.15e-04 ║ S  │     5 │ 0.062500 ║     1 │ 0.030905   ║
# Polishing not needed - no active set detected at optimal point
#   46 ║ 1.000000 │  0.49237999307 ║  0.49227878840 ║   -  │ 1.01e-04 ║ S  │     4 │ 0.125000 ║     1 │ 0.047141   ║
# Polishing not needed - no active set detected at optimal point
#   47 ║ 1.000000 │  0.49234607665 ║  0.49225437127 ║   -  │ 9.17e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.042696   ║
# Polishing not needed - no active set detected at optimal point
#   48 ║ 1.000000 │  0.49232892072 ║  0.49223974061 ║   -  │ 8.92e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.021154   ║
# Polishing not needed - no active set detected at optimal point
#   49 ║ 1.000000 │  0.49228686548 ║  0.49220817643 ║   -  │ 7.87e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.045600   ║
# Polishing not needed - no active set detected at optimal point
#   50 ║ 1.000000 │  0.49225009818 ║  0.49217494722 ║   -  │ 7.52e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.032163   ║
# Polishing not needed - no active set detected at optimal point
#   51 ║ 1.000000 │  0.49224539663 ║  0.49217239321 ║   -  │ 7.30e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.026919   ║
# Polishing not needed - no active set detected at optimal point
#   52 ║ 1.000000 │  0.49224251076 ║  0.49217802243 ║   -  │ 6.45e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.058874   ║
# Polishing not needed - no active set detected at optimal point
#   53 ║ 1.000000 │  0.49221593226 ║  0.49215460510 ║   -  │ 6.13e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.029462   ║
# Polishing not needed - no active set detected at optimal point
#   54 ║ 1.000000 │  0.49220768756 ║  0.49214812027 ║   -  │ 5.96e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.025235   ║
# Polishing not needed - no active set detected at optimal point
#   55 ║ 1.000000 │  0.49215269004 ║  0.49210014860 ║   -  │ 5.25e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.038164   ║
# Polishing not needed - no active set detected at optimal point
#   56 ║ 1.000000 │  0.49214463596 ║  0.49209271355 ║   -  │ 5.19e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.027221   ║
# Polishing not needed - no active set detected at optimal point
#   57 ║ 1.000000 │  0.49213756739 ║  0.49208723420 ║   -  │ 5.03e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.022509   ║
# Polishing not needed - no active set detected at optimal point
#   58 ║ 1.000000 │  0.49213731327 ║  0.49209259592 ║   -  │ 4.47e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.055020   ║
# Polishing not needed - no active set detected at optimal point
#   59 ║ 1.000000 │  0.49213006239 ║  0.49208591126 ║   -  │ 4.42e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.017174   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   60 ║ 1.000000 │  0.49212731751 ║  0.49208854433 ║   -  │ 3.88e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.051779   ║
# Polishing not needed - no active set detected at optimal point
#   61 ║ 1.000000 │  0.49210887520 ║  0.49207211095 ║   -  │ 3.68e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.023798   ║
# Polishing not needed - no active set detected at optimal point
#   62 ║ 1.000000 │  0.49210368978 ║  0.49206747061 ║   -  │ 3.62e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.013265   ║
# Polishing not needed - no active set detected at optimal point
#   63 ║ 1.000000 │  0.49208463238 ║  0.49205059040 ║   -  │ 3.40e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.023567   ║
# Polishing not needed - no active set detected at optimal point
#   64 ║ 1.000000 │  0.49208265360 ║  0.49204907225 ║   -  │ 3.36e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.026100   ║
# Polishing not needed - no active set detected at optimal point
#   65 ║ 1.000000 │  0.49208121753 ║  0.49205163641 ║   -  │ 2.96e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.064044   ║
# Polishing not needed - no active set detected at optimal point
#   66 ║ 1.000000 │  0.49206351321 ║  0.49203429725 ║   -  │ 2.92e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.008194   ║
# Polishing not needed - no active set detected at optimal point
#   67 ║ 1.000000 │  0.49206036342 ║  0.49203204989 ║   -  │ 2.83e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.020110   ║
# Polishing not needed - no active set detected at optimal point
#   68 ║ 1.000000 │  0.49204042855 ║  0.49201378675 ║   -  │ 2.66e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.039043   ║
# Polishing not needed - no active set detected at optimal point
#   69 ║ 1.000000 │  0.49203696729 ║  0.49201049515 ║   -  │ 2.65e-05 ║ S  │     8 │ 0.007812 ║     1 │ 0.021310   ║
# Polishing not needed - no active set detected at optimal point
#   70 ║ 1.000000 │  0.49203371691 ║  0.49201049130 ║   -  │ 2.32e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.054529   ║
# Polishing not needed - no active set detected at optimal point
#   71 ║ 1.000000 │  0.49203092613 ║  0.49200798981 ║   -  │ 2.29e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.018383   ║
# Polishing not needed - no active set detected at optimal point
#   72 ║ 1.000000 │  0.49202975136 ║  0.49200823090 ║   -  │ 2.15e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.037435   ║
# Polishing not needed - no active set detected at optimal point
#   73 ║ 1.000000 │  0.49201615526 ║  0.49199527590 ║   -  │ 2.09e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.008683   ║
# Polishing not needed - no active set detected at optimal point
#   74 ║ 1.000000 │  0.49201527915 ║  0.49199456006 ║   -  │ 2.07e-05 ║ S  │     8 │ 0.007812 ║     2 │ 0.001297   ║
# Polishing not needed - no active set detected at optimal point
#   75 ║ 1.000000 │  0.49200995286 ║  0.49199049201 ║   -  │ 1.95e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.056764   ║
# Polishing not needed - no active set detected at optimal point
#   76 ║ 1.000000 │  0.49200647563 ║  0.49198713375 ║   -  │ 1.93e-05 ║ S  │     8 │ 0.007812 ║     1 │ 0.020110   ║
# Polishing not needed - no active set detected at optimal point
#   77 ║ 1.000000 │  0.49200480006 ║  0.49199504531 ║   -  │ 9.75e-06 ║ S  │     2 │ 0.500000 ║     1 │ 0.001286   ║
# Polishing not needed - no active set detected at optimal point
#   78 ║ 1.000000 │  0.49198320870 ║  0.49198311238 ║   -  │ 9.63e-08 ║ S  │     1 │ 1.000000 ║     1 │ 0.001150   ║
# Polishing not needed - no active set detected at optimal point
#   79 ║ 1.000000 │  0.49198186328 ║  0.49198175832 ║   -  │ 1.05e-07 ║ S  │     2 │ 0.500000 ║     1 │ 0.001453   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   80 ║ 1.000000 │  0.49197689465 ║  0.49197679422 ║   -  │ 1.00e-07 ║ S  │     2 │ 0.500000 ║     1 │ 0.001300   ║
# Polishing not needed - no active set detected at optimal point
#   81 ║ 1.000000 │  0.49196554321 ║  0.49196545371 ║   -  │ 8.95e-08 ║ S  │     3 │ 0.250000 ║     1 │ 4.73e-04   ║
# Polishing not needed - no active set detected at optimal point
#   82 ║ 1.000000 │  0.49195602744 ║  0.49195595244 ║   -  │ 7.50e-08 ║ S  │     3 │ 0.250000 ║     2 │ 1.97e-04   ║
# Polishing not needed - no active set detected at optimal point
#   83 ║ 1.000000 │  0.49195295704 ║  0.49195288965 ║   -  │ 6.74e-08 ║ S  │     4 │ 0.125000 ║     2 │ 1.84e-04   ║
# Polishing not needed - no active set detected at optimal point
#   84 ║ 1.000000 │  0.49195235702 ║  0.49195229548 ║   -  │ 6.15e-08 ║ S  │     4 │ 0.125000 ║     3 │ 1.39e-04   ║
# Polishing not needed - no active set detected at optimal point
#   85 ║ 1.000000 │  0.49195172379 ║  0.49195167530 ║   -  │ 4.85e-08 ║ S  │     3 │ 0.250000 ║     3 │ 1.20e-04   ║
# Polishing not needed - no active set detected at optimal point
#   86 ║ 1.000000 │  0.49195021782 ║  0.49195017434 ║   -  │ 4.35e-08 ║ S  │     4 │ 0.125000 ║     3 │ 1.17e-04   ║
# Polishing not needed - no active set detected at optimal point
#   87 ║ 1.000000 │  0.49194905451 ║  0.49194901567 ║   -  │ 3.88e-08 ║ S  │     4 │ 0.125000 ║     3 │ 1.10e-04   ║
# Polishing not needed - no active set detected at optimal point
#   88 ║ 1.000000 │  0.49194842875 ║  0.49194839416 ║   -  │ 3.46e-08 ║ S  │     4 │ 0.125000 ║     4 │ 1.01e-04   ║
# Polishing not needed - no active set detected at optimal point
#   89 ║ 1.000000 │  0.49194749053 ║  0.49194745949 ║   -  │ 3.10e-08 ║ S  │     4 │ 0.125000 ║     4 │ 1.20e-04   ║
# Polishing not needed - no active set detected at optimal point
#   90 ║ 1.000000 │  0.49194701031 ║  0.49194698105 ║   -  │ 2.93e-08 ║ S  │     5 │ 0.062500 ║     5 │ 6.92e-05   ║
# Polishing not needed - no active set detected at optimal point
#   91 ║ 1.000000 │  0.49194657512 ║  0.49194654918 ║   -  │ 2.59e-08 ║ S  │     4 │ 0.125000 ║     5 │ 5.48e-05   ║
# Polishing not needed - no active set detected at optimal point
#   92 ║ 1.000000 │  0.49194601778 ║  0.49194599475 ║   -  │ 2.30e-08 ║ S  │     4 │ 0.125000 ║     5 │ 8.66e-05   ║
# Polishing not needed - no active set detected at optimal point
#   93 ║ 1.000000 │  0.49194601246 ║  0.49194599069 ║   -  │ 2.18e-08 ║ S  │     5 │ 0.062500 ║     6 │ 4.63e-05   ║
# Polishing not needed - no active set detected at optimal point
#   94 ║ 1.000000 │  0.49194555119 ║  0.49194553197 ║   -  │ 1.92e-08 ║ S  │     4 │ 0.125000 ║     6 │ 4.62e-05   ║
# Polishing not needed - no active set detected at optimal point
#   95 ║ 1.000000 │  0.49194500450 ║  0.49194498640 ║   -  │ 1.81e-08 ║ S  │     5 │ 0.062500 ║     7 │ 4.27e-05   ║
# Polishing not needed - no active set detected at optimal point
#   96 ║ 1.000000 │  0.49194467154 ║  0.49194465449 ║   -  │ 1.71e-08 ║ S  │     5 │ 0.062500 ║     8 │ 3.36e-05   ║
# Polishing not needed - no active set detected at optimal point
#   97 ║ 1.000000 │  0.49194461118 ║  0.49194459510 ║   -  │ 1.61e-08 ║ S  │     5 │ 0.062500 ║     8 │ 2.34e-05   ║
# Polishing not needed - no active set detected at optimal point
#   98 ║ 1.000000 │  0.49194434527 ║  0.49194433016 ║   -  │ 1.51e-08 ║ S  │     5 │ 0.062500 ║     9 │ 1.67e-05   ║
# Polishing not needed - no active set detected at optimal point
#   99 ║ 1.000000 │  0.49194407048 ║  0.49194405582 ║   -  │ 1.47e-08 ║ S  │     6 │ 0.031250 ║     9 │ 1.98e-05   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  100 ║ 1.000000 │  0.49194382838 ║  0.49194381416 ║   -  │ 1.42e-08 ║ S  │     6 │ 0.031250 ║    10 │ 1.28e-05   ║
# Polishing not needed - no active set detected at optimal point
#  101 ║ 1.000000 │  0.49194376834 ║  0.49194375496 ║   -  │ 1.34e-08 ║ S  │     5 │ 0.062500 ║    11 │ 1.46e-05   ║
# Polishing not needed - no active set detected at optimal point
#  102 ║ 1.000000 │  0.49194365560 ║  0.49194364263 ║   -  │ 1.30e-08 ║ S  │     6 │ 0.031250 ║    12 │ 6.52e-06   ║
# Polishing not needed - no active set detected at optimal point
#  103 ║ 1.000000 │  0.49194344254 ║  0.49194343116 ║   -  │ 1.14e-08 ║ S  │     4 │ 0.125000 ║    12 │ 4.84e-06   ║
# Polishing not needed - no active set detected at optimal point
#  104 ║ 1.000000 │  0.49194321209 ║  0.49194320105 ║   -  │ 1.10e-08 ║ S  │     6 │ 0.031250 ║    13 │ 4.86e-06   ║
# Polishing not needed - no active set detected at optimal point
#  105 ║ 1.000000 │  0.49194315470 ║  0.49194314400 ║   -  │ 1.07e-08 ║ S  │     6 │ 0.031250 ║    14 │ 2.45e-06   ║
# Polishing not needed - no active set detected at optimal point
#  106 ║ 1.000000 │  0.49194301059 ║  0.49194300122 ║   -  │ 9.38e-09 ║ S  │     4 │ 0.125000 ║    15 │ 1.31e-06   ║
# Polishing not needed - no active set detected at optimal point
#  107 ║ 1.000000 │  0.49194291840 ║  0.49194290931 ║   -  │ 9.09e-09 ║ S  │     6 │ 0.031250 ║    16 │ 7.50e-07   ║
# Polishing not needed - no active set detected at optimal point
#  108 ║ 1.000000 │  0.49194285381 ║  0.49194284486 ║   -  │ 8.95e-09 ║ S  │     7 │ 0.015625 ║    17 │ 8.82e-07   ║
# Polishing not needed - no active set detected at optimal point
#  109 ║ 1.000000 │  0.49194282734 ║  0.49194281894 ║   -  │ 8.40e-09 ║ S  │     5 │ 0.062500 ║    17 │ 7.20e-07   ║
# Polishing not needed - no active set detected at optimal point
#  110 ║ 1.000000 │  0.49194277900 ║  0.49194277111 ║   -  │ 7.88e-09 ║ S  │     5 │ 0.062500 ║    18 │ 6.93e-07   ║
# Polishing not needed - no active set detected at optimal point
#  111 ║ 1.000000 │  0.49194275488 ║  0.49194274712 ║   -  │ 7.76e-09 ║ S  │     7 │ 0.015625 ║    19 │ 7.96e-07   ║
# Polishing not needed - no active set detected at optimal point
#  112 ║ 1.000000 │  0.49194274001 ║  0.49194273249 ║   -  │ 7.52e-09 ║ S  │     6 │ 0.031250 ║    20 │ 5.90e-07   ║
# Polishing not needed - no active set detected at optimal point
#  113 ║ 1.000000 │  0.49194266666 ║  0.49194265961 ║   -  │ 7.05e-09 ║ S  │     5 │ 0.062500 ║    21 │ 4.27e-07   ║
# Polishing not needed - no active set detected at optimal point
#  114 ║ 1.000000 │  0.49194263960 ║  0.49194263266 ║   -  │ 6.95e-09 ║ S  │     7 │ 0.015625 ║    22 │ 5.23e-07   ║
# Polishing not needed - no active set detected at optimal point
#  115 ║ 1.000000 │  0.49194263051 ║  0.49194262399 ║   -  │ 6.51e-09 ║ S  │     5 │ 0.062500 ║    23 │ 3.01e-07   ║
# Polishing not needed - no active set detected at optimal point
#  116 ║ 1.000000 │  0.49194251527 ║  0.49194250916 ║   -  │ 6.11e-09 ║ S  │     5 │ 0.062500 ║    23 │ 4.67e-07   ║
# Polishing not needed - no active set detected at optimal point
#  117 ║ 1.000000 │  0.49194249802 ║  0.49194249200 ║   -  │ 6.02e-09 ║ S  │     7 │ 0.015625 ║    24 │ 3.86e-07   ║
# Polishing not needed - no active set detected at optimal point
#  118 ║ 1.000000 │  0.49194245311 ║  0.49194244747 ║   -  │ 5.64e-09 ║ S  │     5 │ 0.062500 ║    25 │ 2.86e-07   ║
# Polishing not needed - no active set detected at optimal point
#  119 ║ 1.000000 │  0.49194243768 ║  0.49194243213 ║   -  │ 5.55e-09 ║ S  │     7 │ 0.015625 ║    26 │ 2.59e-07   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  120 ║ 1.000000 │  0.49194243076 ║  0.49194242538 ║   -  │ 5.38e-09 ║ S  │     6 │ 0.031250 ║    27 │ 1.92e-07   ║
# Polishing not needed - no active set detected at optimal point
#  121 ║ 1.000000 │  0.49194239759 ║  0.49194239254 ║   -  │ 5.05e-09 ║ S  │     5 │ 0.062500 ║    28 │ 1.89e-07   ║
# Polishing not needed - no active set detected at optimal point
#  122 ║ 1.000000 │  0.49194237619 ║  0.49194237177 ║   -  │ 4.42e-09 ║ S  │     4 │ 0.125000 ║    29 │ 1.13e-07   ║
# Polishing not needed - no active set detected at optimal point
#  123 ║ 1.000000 │  0.49194234287 ║  0.49194233901 ║   -  │ 3.87e-09 ║ S  │     4 │ 0.125000 ║    30 │ 1.27e-07   ║
# Polishing not needed - no active set detected at optimal point
#  124 ║ 1.000000 │  0.49194228770 ║  0.49194228431 ║   -  │ 3.38e-09 ║ S  │     4 │ 0.125000 ║    31 │ 8.06e-08   ║
# Polishing not needed - no active set detected at optimal point
#  125 ║ 1.000000 │  0.49194225895 ║  0.49194225599 ║   -  │ 2.96e-09 ║ S  │     4 │ 0.125000 ║    32 │ 7.62e-08   ║
# Polishing not needed - no active set detected at optimal point
#  126 ║ 1.000000 │  0.49194222771 ║  0.49194222512 ║   -  │ 2.59e-09 ║ S  │     4 │ 0.125000 ║    33 │ 7.74e-08   ║
# Polishing not needed - no active set detected at optimal point
#  127 ║ 1.000000 │  0.49194221303 ║  0.49194221060 ║   -  │ 2.43e-09 ║ S  │     5 │ 0.062500 ║    34 │ 6.85e-08   ║
# Polishing not needed - no active set detected at optimal point
#  128 ║ 1.000000 │  0.49194220066 ║  0.49194219839 ║   -  │ 2.28e-09 ║ S  │     5 │ 0.062500 ║    35 │ 5.96e-08   ║
# Polishing not needed - no active set detected at optimal point
#  129 ║ 1.000000 │  0.49194219082 ║  0.49194218868 ║   -  │ 2.13e-09 ║ S  │     5 │ 0.062500 ║    36 │ 6.13e-08   ║
# Polishing not needed - no active set detected at optimal point
#  130 ║ 1.000000 │  0.49194218028 ║  0.49194217841 ║   -  │ 1.87e-09 ║ S  │     4 │ 0.125000 ║    37 │ 5.69e-08   ║
# Polishing not needed - no active set detected at optimal point
#  131 ║ 1.000000 │  0.49194217486 ║  0.49194217323 ║   -  │ 1.63e-09 ║ S  │     4 │ 0.125000 ║    38 │ 5.12e-08   ║
# Polishing not needed - no active set detected at optimal point
#  132 ║ 1.000000 │  0.49194216939 ║  0.49194216781 ║   -  │ 1.58e-09 ║ S  │     6 │ 0.031250 ║    39 │ 3.60e-08   ║
# Polishing not needed - no active set detected at optimal point
#  133 ║ 1.000000 │  0.49194216553 ║  0.49194216404 ║   -  │ 1.48e-09 ║ S  │     5 │ 0.062500 ║    40 │ 3.68e-08   ║
# Polishing not needed - no active set detected at optimal point
#  134 ║ 1.000000 │  0.49194215960 ║  0.49194215830 ║   -  │ 1.30e-09 ║ S  │     4 │ 0.125000 ║    40 │ 1.29e-08   ║
# Polishing not needed - no active set detected at optimal point
#  135 ║ 1.000000 │  0.49194215310 ║  0.49194215188 ║   -  │ 1.22e-09 ║ S  │     5 │ 0.062500 ║    40 │ 1.76e-08   ║
# Polishing not needed - no active set detected at optimal point
#  136 ║ 1.000000 │  0.49194214831 ║  0.49194214716 ║   -  │ 1.14e-09 ║ S  │     5 │ 0.062500 ║    40 │ 1.68e-08   ║
# Polishing not needed - no active set detected at optimal point
#  137 ║ 1.000000 │  0.49194214386 ║  0.49194214279 ║   -  │ 1.07e-09 ║ S  │     5 │ 0.062500 ║    40 │ 1.59e-08   ║
# Polishing not needed - no active set detected at optimal point
#  138 ║ 1.000000 │  0.49194213940 ║  0.49194213840 ║   -  │ 1.00e-09 ║ S  │     5 │ 0.062500 ║    40 │ 1.29e-08   ║
# Polishing not needed - no active set detected at optimal point
#  139 ║ 1.000000 │  0.49194213525 ║  0.49194213431 ║   -  │ 9.41e-10 ║ S  │     5 │ 0.062500 ║    40 │ 1.47e-08   ║
# Polishing not needed - no active set detected at optimal point
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  140 ║ 1.000000 │  0.49194213276 ║  0.49194213188 ║   -  │ 8.82e-10 ║ S  │     5 │ 0.062500 ║    40 │ 2.79e-08   ║
# Polishing not needed - no active set detected at optimal point
#  141 ║ 1.000000 │  0.49194212952 ║  0.49194212870 ║   -  │ 8.27e-10 ║ S  │     5 │ 0.062500 ║    40 │ 2.77e-08   ║
# Polishing not needed - no active set detected at optimal point
#  142 ║ 1.000000 │  0.49194212693 ║  0.49194212616 ║   -  │ 7.75e-10 ║ S  │     5 │ 0.062500 ║    40 │ 1.38e-08   ║
# Polishing not needed - no active set detected at optimal point
#  143 ║ 1.000000 │  0.49194212667 ║  0.49194212599 ║   -  │ 6.78e-10 ║ S  │     4 │ 0.125000 ║    40 │ 2.53e-08   ║
# Polishing not needed - no active set detected at optimal point
#  144 ║ 1.000000 │  0.49194212512 ║  0.49194212446 ║   -  │ 6.57e-10 ║ S  │     6 │ 0.031250 ║    40 │ 1.93e-08   ║
# Polishing not needed - no active set detected at optimal point
#  145 ║ 1.000000 │  0.49194212339 ║  0.49194212276 ║   -  │ 6.37e-10 ║ S  │     6 │ 0.031250 ║    40 │ 5.32e-10   ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                                            ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                                   ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#    F ║          │                ║  0.49194212276 ║   -  │ 6.37e-10 ║    │       │          ║       │            ║
#    B ║          │                ║  0.49194212276 ║   -  │ 6.37e-10 ║    │       │          ║       │            ║
#   MF ║          │                ║  0.61751624522 ║   -  │ 2.22e-16 ║    │       │          ║       │            ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Iterations:              145                                                                                     ║
# Function evaluations:    581                                                                                     ║
# PyGRANSO termination code: 0 --- converged to stationarity and feasibility tolerances.                           ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# Total Wall Time: 10.850968837738037s
# tensor([1.0000], dtype=torch.float64)

# %% [markdown]
# # CUDA Version

# %%
device = torch.device('cuda')
n = 30

np.random.seed(1)
m = 10*n**2   # sample complexity
theta = 0.3   # sparsity level
Y = norm.ppf(np.random.rand(n,m)) * (norm.ppf(np.random.rand(n,m)) <= theta)  # Bernoulli-Gaussian model

# All the user-provided data (vector/matrix/tensor) must be in torch tensor format. 
# As PyTorch tensor is single precision by default, one must explicitly set `dtype=torch.double`.
# Also, please make sure the device of provided torch tensor is the same as opts.torch_device.
Y = torch.from_numpy(Y).to(device=device, dtype=torch.double)

# %%
# variables and corresponding dimensions.
var_in = {"q": [n,1]}

def user_fn(X_struct,Y):
    q = X_struct.q
    
    # objective function
    qtY = q.T @ Y
    f = 1/m * torch.norm(qtY, p = 1)

    # inequality constraint, matrix form
    ci = None

    # equality constraint 
    ce = pygransoStruct()
    ce.c1 = q.T @ q - 1

    return [f,ci,ce]

comb_fn = lambda X_struct : user_fn(X_struct,Y)

# %%
opts = pygransoStruct()
opts.torch_device = device
opts.maxit = 500
np.random.seed(1)
x0 = norm.ppf(np.random.rand(n,1))
x0 /= la.norm(x0,2)
opts.x0 = torch.from_numpy(x0).to(
    device=device,
    dtype=torch.double
)

opts.print_frequency = 1

# %%
start = time.time()
cuda_soln = pygranso(
    var_spec=var_in,
    combined_fn=comb_fn,
    user_opts=opts
)
end = time.time()

print("Total Wall Time: {}s".format(end - start))
print(max(abs(cuda_soln.final.x))) # should be close to 1
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                                             ║
# Version 1.2.0                                                                                                    ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang                                  ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                                          ║
#  # of variables                     :   30                                                                       ║
#  # of inequality constraints        :    0                                                                       ║
#  # of equality constraints          :    1                                                                       ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#    0 ║ 1.000000 │  0.61751624522 ║  0.61751624522 ║   -  │ 0.000000 ║ -  │     1 │ 0.000000 ║     1 │ 0.054664   ║
# Polishing not needed - no active set detected at optimal point
# Polishing not needed - no active set detected at optimal point
#    1 ║ 0.348678 │  0.21523331471 ║  0.61702265809 ║   -  │ 9.08e-05 ║ S  │     2 │ 0.500000 ║     1 │ 0.019033   ║
#    2 ║ 0.348678 │  0.21505415836 ║  0.61655168417 ║   -  │ 7.59e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008529   ║
#    3 ║ 0.348678 │  0.21489218411 ║  0.61609743698 ║   -  │ 7.23e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008528   ║
#    4 ║ 0.348678 │  0.21473393416 ║  0.61563533541 ║   -  │ 7.52e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008531   ║
#    5 ║ 0.348678 │  0.21457308635 ║  0.61518148843 ║   -  │ 7.26e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008470   ║
#    6 ║ 0.348678 │  0.21441667028 ║  0.61473503399 ║   -  │ 7.18e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008501   ║
#    7 ║ 0.348678 │  0.21426070441 ║  0.61428334084 ║   -  │ 7.33e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008502   ║
#    8 ║ 0.348678 │  0.21410757815 ║  0.61384321252 ║   -  │ 7.37e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008397   ║
#    9 ║ 0.348678 │  0.21395288573 ║  0.61341505295 ║   -  │ 6.83e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008352   ║
#   10 ║ 0.348678 │  0.21379957914 ║  0.61296562580 ║   -  │ 7.17e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008657   ║
#   11 ║ 0.348678 │  0.21364307338 ║  0.61249809244 ║   -  │ 7.82e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008893   ║
#   12 ║ 0.348678 │  0.21347706441 ║  0.61202180437 ║   -  │ 7.83e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008896   ║
#   13 ║ 0.348678 │  0.21330919968 ║  0.61154218315 ║   -  │ 7.76e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008661   ║
#   14 ║ 0.348678 │  0.21314441578 ║  0.61108523512 ║   -  │ 7.22e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008574   ║
#   15 ║ 0.348678 │  0.21298338696 ║  0.61061612948 ║   -  │ 7.47e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008719   ║
#   16 ║ 0.348678 │  0.21281936575 ║  0.61014358943 ║   -  │ 7.55e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008712   ║
#   17 ║ 0.348678 │  0.21265296315 ║  0.60967034855 ║   -  │ 7.41e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.008888   ║
#   18 ║ 0.348678 │  0.21248673232 ║  0.60916368722 ║   -  │ 8.45e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009237   ║
#   19 ║ 0.348678 │  0.21230592359 ║  0.60865049402 ║   -  │ 8.26e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009235   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   20 ║ 0.348678 │  0.21212099838 ║  0.60809807000 ║   -  │ 9.03e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009865   ║
#   21 ║ 0.348678 │  0.21192661219 ║  0.60750847570 ║   -  │ 1.02e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.009884   ║
#   22 ║ 0.348678 │  0.21172070149 ║  0.60695565946 ║   -  │ 8.83e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009425   ║
#   23 ║ 0.348678 │  0.21152611824 ║  0.60639636148 ║   -  │ 8.88e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009562   ║
#   24 ║ 0.348678 │  0.21132666925 ║  0.60579929964 ║   -  │ 9.75e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.010128   ║
#   25 ║ 0.348678 │  0.21111573713 ║  0.60518215748 ║   -  │ 1.02e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010062   ║
#   26 ║ 0.348678 │  0.21090028581 ║  0.60457574408 ║   -  │ 9.78e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009892   ║
#   27 ║ 0.348678 │  0.21068690200 ║  0.60395705262 ║   -  │ 1.00e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010168   ║
#   28 ║ 0.348678 │  0.21047306708 ║  0.60333102513 ║   -  │ 1.05e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010064   ║
#   29 ║ 0.348678 │  0.21025198424 ║  0.60272346185 ║   -  │ 9.53e-05 ║ S  │     1 │ 1.000000 ║     1 │ 0.009887   ║
#   30 ║ 0.348678 │  0.21003903969 ║  0.60209325803 ║   -  │ 1.02e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010253   ║
#   31 ║ 0.348678 │  0.20981792878 ║  0.60145067041 ║   -  │ 1.05e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010139   ║
#   32 ║ 0.348678 │  0.20959290804 ║  0.60081345161 ║   -  │ 1.02e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010161   ║
#   33 ║ 0.348678 │  0.20936882689 ║  0.60016273533 ║   -  │ 1.05e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010396   ║
#   34 ║ 0.348678 │  0.20913851968 ║  0.59949669309 ║   -  │ 1.07e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.010670   ║
#   35 ║ 0.348678 │  0.20889647806 ║  0.59877011169 ║   -  │ 1.18e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.011082   ║
#   36 ║ 0.348678 │  0.20864493095 ║  0.59803949723 ║   -  │ 1.21e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.011035   ║
#   37 ║ 0.348678 │  0.20838226051 ║  0.59729893025 ║   -  │ 1.17e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.011076   ║
#   38 ║ 0.348678 │  0.20811907111 ║  0.59650939477 ║   -  │ 1.29e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.011670   ║
#   39 ║ 0.348678 │  0.20784033044 ║  0.59568550498 ║   -  │ 1.38e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.011742   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   40 ║ 0.348678 │  0.20754531083 ║  0.59485919467 ║   -  │ 1.31e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.011788   ║
#   41 ║ 0.348678 │  0.20724981169 ║  0.59395707878 ║   -  │ 1.50e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.012714   ║
#   42 ║ 0.348678 │  0.20692379300 ║  0.59299004912 ║   -  │ 1.61e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.012964   ║
#   43 ║ 0.348678 │  0.20657625996 ║  0.59199632823 ║   -  │ 1.60e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.012838   ║
#   44 ║ 0.348678 │  0.20623106504 ║  0.59099670660 ║   -  │ 1.63e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.012894   ║
#   45 ║ 0.348678 │  0.20587423219 ║  0.58997339915 ║   -  │ 1.63e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.013277   ║
#   46 ║ 0.348678 │  0.20550551454 ║  0.58885406997 ║   -  │ 1.85e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.013948   ║
#   47 ║ 0.348678 │  0.20510393938 ║  0.58768202404 ║   -  │ 1.92e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.014134   ║
#   48 ║ 0.348678 │  0.20467656600 ║  0.58644005219 ║   -  │ 1.98e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.014774   ║
#   49 ║ 0.348678 │  0.20422746729 ║  0.58505017660 ║   -  │ 2.33e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.015715   ║
#   50 ║ 0.348678 │  0.20372390101 ║  0.58360423128 ║   -  │ 2.34e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.015876   ║
#   51 ║ 0.348678 │  0.20319591193 ║  0.58200524838 ║   -  │ 2.63e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.016887   ║
#   52 ║ 0.348678 │  0.20261573361 ║  0.58028617677 ║   -  │ 2.82e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.017507   ║
#   53 ║ 0.348678 │  0.20199142240 ║  0.57842732075 ║   -  │ 3.06e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.017979   ║
#   54 ║ 0.348678 │  0.20131644737 ║  0.57647230127 ║   -  │ 3.13e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.018728   ║
#   55 ║ 0.348678 │  0.20059714371 ║  0.57423431944 ║   -  │ 3.74e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.020287   ║
#   56 ║ 0.348678 │  0.19977679506 ║  0.57180186558 ║   -  │ 4.02e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.020750   ║
#   57 ║ 0.348678 │  0.19890393383 ║  0.56922971658 ║   -  │ 4.26e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.020894   ║
#   58 ║ 0.348678 │  0.19800259664 ║  0.56665105135 ║   -  │ 4.24e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.020756   ║
#   59 ║ 0.348678 │  0.19707137875 ║  0.56397908371 ║   -  │ 4.24e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.021353   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   60 ║ 0.348678 │  0.19610374466 ║  0.56103769184 ║   -  │ 4.82e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.022739   ║
#   61 ║ 0.348678 │  0.19505323340 ║  0.55793306482 ║   -  │ 5.14e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.023002   ║
#   62 ║ 0.348678 │  0.19393803993 ║  0.55473962756 ║   -  │ 5.12e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.023336   ║
#   63 ║ 0.348678 │  0.19279359217 ║  0.55130634068 ║   -  │ 5.65e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.024492   ║
#   64 ║ 0.348678 │  0.19154065902 ║  0.54761496922 ║   -  │ 5.99e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.025571   ║
#   65 ║ 0.348678 │  0.19020015359 ║  0.54356691241 ║   -  │ 6.70e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.026914   ║
#   66 ║ 0.348678 │  0.18873302058 ║  0.53921415873 ║   -  │ 7.21e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.027418   ║
#   67 ║ 0.348678 │  0.18718431923 ║  0.53477086450 ║   -  │ 7.21e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.027423   ║
#   68 ║ 0.348678 │  0.18558800232 ║  0.53009806055 ║   -  │ 7.54e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.028397   ║
#   69 ║ 0.348678 │  0.18390200197 ║  0.52503953241 ║   -  │ 8.32e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.029762   ║
#   70 ║ 0.348678 │  0.18208803326 ║  0.51970568592 ║   -  │ 8.78e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.030305   ║
#   71 ║ 0.348678 │  0.18017843508 ║  0.51408972289 ║   -  │ 9.26e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.031029   ║
#   72 ║ 0.348678 │  0.17818011100 ║  0.50828431867 ║   -  │ 9.52e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.031692   ║
#   73 ║ 0.348678 │  0.17608538567 ║  0.50199560006 ║   -  │ 0.001050 ║ S  │     1 │ 1.000000 ║     1 │ 0.033271   ║
#   74 ║ 0.348678 │  0.17388254413 ║  0.49521403097 ║   -  │ 0.001212 ║ S  │     1 │ 1.000000 ║     1 │ 0.033688   ║
#   75 ║ 0.348678 │  0.17346372663 ║  0.49433525059 ║   -  │ 0.001100 ║ S  │     2 │ 0.500000 ║     1 │ 0.051251   ║
#   76 ║ 0.348678 │  0.17207997609 ║  0.49318929090 ║   -  │ 1.16e-04 ║ S  │     1 │ 1.000000 ║     1 │ 0.033057   ║
#   77 ║ 0.348678 │  0.17191600830 ║  0.49274685772 ║   -  │ 1.06e-04 ║ S  │     3 │ 0.250000 ║     1 │ 0.014876   ║
#   78 ║ 0.348678 │  0.17180532574 ║  0.49248201756 ║   -  │ 8.75e-05 ║ S  │     3 │ 0.250000 ║     1 │ 0.019779   ║
#   79 ║ 0.348678 │  0.17173707782 ║  0.49230969919 ║   -  │ 7.93e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.011917   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#   80 ║ 0.348678 │  0.17171228888 ║  0.49226239425 ║   -  │ 7.10e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.018068   ║
#   81 ║ 0.348678 │  0.17168571364 ║  0.49220931710 ║   -  │ 6.29e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.018479   ║
#   82 ║ 0.348678 │  0.17166932949 ║  0.49217996777 ║   -  │ 5.68e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.019548   ║
#   83 ║ 0.348678 │  0.17166884530 ║  0.49219675155 ║   -  │ 5.04e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.022540   ║
#   84 ║ 0.348678 │  0.17165605777 ║  0.49222496522 ║   -  │ 2.78e-05 ║ S  │     2 │ 0.500000 ║     1 │ 0.028833   ║
#   85 ║ 0.348678 │  0.17163888521 ║  0.49217936953 ║   -  │ 2.66e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.004973   ║
#   86 ║ 0.348678 │  0.17162812357 ║  0.49215716915 ║   -  │ 2.35e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.015416   ║
#   87 ║ 0.348678 │  0.17159712926 ║  0.49207510085 ║   -  │ 2.12e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.013647   ║
#   88 ║ 0.348678 │  0.17159344919 ║  0.49206599297 ║   -  │ 2.06e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.013070   ║
#   89 ║ 0.348678 │  0.17158504822 ║  0.49204901777 ║   -  │ 1.82e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.018606   ║
#   90 ║ 0.348678 │  0.17157612045 ║  0.49202480858 ║   -  │ 1.77e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.007896   ║
#   91 ║ 0.348678 │  0.17157481107 ║  0.49202181211 ║   -  │ 1.74e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.007394   ║
#   92 ║ 0.348678 │  0.17157143591 ║  0.49201812084 ║   -  │ 1.53e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.027409   ║
#   93 ║ 0.348678 │  0.17156529516 ║  0.49200167269 ║   -  │ 1.49e-05 ║ S  │     6 │ 0.031250 ║     1 │ 0.010731   ║
#   94 ║ 0.348678 │  0.17156488439 ║  0.49200113692 ║   -  │ 1.47e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.009300   ║
#   95 ║ 0.348678 │  0.17156289070 ║  0.49199802763 ║   -  │ 1.38e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.014689   ║
#   96 ║ 0.348678 │  0.17156077457 ║  0.49199419307 ║   -  │ 1.30e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.016011   ║
#   97 ║ 0.348678 │  0.17156020762 ║  0.49199311528 ║   -  │ 1.28e-05 ║ S  │     7 │ 0.015625 ║     1 │ 0.008946   ║
#   98 ║ 0.348678 │  0.17155975537 ║  0.49199408625 ║   -  │ 1.20e-05 ║ S  │     5 │ 0.062500 ║     1 │ 0.017480   ║
#   99 ║ 0.348678 │  0.17155751624 ║  0.49199173976 ║   -  │ 1.06e-05 ║ S  │     4 │ 0.125000 ║     1 │ 0.021328   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  100 ║ 0.348678 │  0.17155650882 ║  0.49198907269 ║   -  │ 1.05e-05 ║ S  │     8 │ 0.007812 ║     2 │ 8.21e-04   ║
#  101 ║ 0.348678 │  0.17155495860 ║  0.49198838322 ║   -  │ 9.22e-06 ║ S  │     4 │ 0.125000 ║     1 │ 0.020016   ║
#  102 ║ 0.348678 │  0.17155196454 ║  0.49198127683 ║   -  │ 8.70e-06 ║ S  │     5 │ 0.062500 ║     1 │ 0.013097   ║
#  103 ║ 0.348678 │  0.17155159288 ║  0.49198039974 ║   -  │ 8.63e-06 ║ S  │     8 │ 0.007812 ║     2 │ 8.14e-04   ║
#  104 ║ 0.348678 │  0.17155088253 ║  0.49198141690 ║   -  │ 7.57e-06 ║ S  │     4 │ 0.125000 ║     1 │ 0.023458   ║
#  105 ║ 0.348678 │  0.17154873856 ║  0.49197557928 ║   -  │ 7.46e-06 ║ S  │     7 │ 0.015625 ║     1 │ 0.005056   ║
#  106 ║ 0.348678 │  0.17154849326 ║  0.49197504151 ║   -  │ 7.40e-06 ║ S  │     8 │ 0.007812 ║     2 │ 6.85e-04   ║
#  107 ║ 0.348678 │  0.17154698018 ║  0.49197202328 ║   -  │ 6.94e-06 ║ S  │     5 │ 0.062500 ║     2 │ 6.42e-04   ║
#  108 ║ 0.348678 │  0.17154474750 ║  0.49196589261 ║   -  │ 6.85e-06 ║ S  │     7 │ 0.015625 ║     1 │ 0.013035   ║
#  109 ║ 0.348678 │  0.17154452272 ║  0.49196532317 ║   -  │ 6.82e-06 ║ S  │     9 │ 0.003906 ║     2 │ 8.42e-04   ║
#  110 ║ 0.348678 │  0.17154431856 ║  0.49196595631 ║   -  │ 6.40e-06 ║ S  │     5 │ 0.062500 ║     3 │ 4.26e-04   ║
#  111 ║ 0.348678 │  0.17154270261 ║  0.49196160055 ║   -  │ 6.30e-06 ║ S  │     7 │ 0.015625 ║     2 │ 0.003669   ║
#  112 ║ 0.348678 │  0.17154258091 ║  0.49196132110 ║   -  │ 6.27e-06 ║ S  │     9 │ 0.003906 ║     3 │ 3.94e-04   ║
#  113 ║ 0.348678 │  0.17154145218 ║  0.49196034516 ║   -  │ 5.49e-06 ║ S  │     4 │ 0.125000 ║     3 │ 3.46e-04   ║
#  114 ║ 0.348678 │  0.17154026567 ║  0.49195705631 ║   -  │ 5.45e-06 ║ S  │     8 │ 0.007812 ║     2 │ 8.11e-04   ║
#  115 ║ 0.348678 │  0.17154001079 ║  0.49195681540 ║   -  │ 5.28e-06 ║ S  │     6 │ 0.031250 ║     3 │ 3.12e-04   ║
#  116 ║ 0.348678 │  0.17153913057 ║  0.49195452381 ║   -  │ 5.19e-06 ║ S  │     7 │ 0.015625 ║     3 │ 0.002118   ║
#  117 ║ 0.348678 │  0.17153908520 ║  0.49195445211 ║   -  │ 5.17e-06 ║ S  │     9 │ 0.003906 ║     4 │ 2.16e-04   ║
#  118 ║ 0.348678 │  0.17153785969 ║  0.49195280287 ║   -  │ 4.52e-06 ║ S  │     4 │ 0.125000 ║     3 │ 2.00e-04   ║
#  119 ║ 0.348678 │  0.17153740102 ║  0.49195313452 ║   -  │ 3.95e-06 ║ S  │     4 │ 0.125000 ║     4 │ 1.75e-04   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#      ║ <--- Penalty Function --> ║                ║ Total Violation ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║    Mu    │      Value     ║    Objective   ║ Ineq │    Eq    ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬═══════════════════════════╬════════════════╬═════════════════╬═══════════════════════╬════════════════════╣
#  120 ║ 0.348678 │  0.17153721857 ║  0.49195269608 ║   -  │ 3.92e-06 ║ S  │     8 │ 0.007812 ║     3 │ 2.33e-04   ║
#  121 ║ 0.348678 │  0.17153676622 ║  0.49195423858 ║   -  │ 2.93e-06 ║ S  │     3 │ 0.250000 ║     2 │ 8.85e-05   ║
#  122 ║ 0.348678 │  0.17153512310 ║  0.49195379231 ║   -  │ 1.44e-06 ║ S  │     2 │ 0.500000 ║     2 │ 6.95e-05   ║
#  123 ║ 0.348678 │  0.17153381879 ║  0.49195217406 ║   -  │ 7.02e-07 ║ S  │     2 │ 0.500000 ║     2 │ 7.38e-05   ║
#  124 ║ 0.348678 │  0.17153266115 ║  0.49194938949 ║   -  │ 5.15e-07 ║ S  │     3 │ 0.250000 ║     3 │ 1.16e-04   ║
#  125 ║ 0.348678 │  0.17153251576 ║  0.49194917078 ║   -  │ 4.46e-07 ║ S  │     4 │ 0.125000 ║     3 │ 7.67e-05   ║
#  126 ║ 0.348678 │  0.17153184716 ║  0.49194761514 ║   -  │ 3.20e-07 ║ S  │     3 │ 0.250000 ║     4 │ 5.19e-05   ║
#  127 ║ 0.348678 │  0.17153126930 ║  0.49194622813 ║   -  │ 2.26e-07 ║ S  │     3 │ 0.250000 ║     4 │ 3.47e-05   ║
#  128 ║ 0.348678 │  0.17153089540 ║  0.49194536780 ║   -  │ 1.52e-07 ║ S  │     3 │ 0.250000 ║     4 │ 3.52e-05   ║
#  129 ║ 0.348678 │  0.17153065579 ║  0.49194475002 ║   -  │ 1.28e-07 ║ S  │     4 │ 0.125000 ║     5 │ 1.95e-05   ║
#  130 ║ 0.348678 │  0.17153039981 ║  0.49194407789 ║   -  │ 1.06e-07 ║ S  │     4 │ 0.125000 ║     6 │ 1.12e-05   ║
#  131 ║ 0.348678 │  0.17153034681 ║  0.49194404416 ║   -  │ 6.49e-08 ║ S  │     3 │ 0.250000 ║     6 │ 1.02e-05   ║
#  132 ║ 0.348678 │  0.17153021281 ║  0.49194370092 ║   -  │ 5.06e-08 ║ S  │     4 │ 0.125000 ║     7 │ 5.86e-06   ║
#  133 ║ 0.348678 │  0.17153012687 ║  0.49194348634 ║   -  │ 3.94e-08 ║ S  │     4 │ 0.125000 ║     8 │ 4.68e-06   ║
#  134 ║ 0.348678 │  0.17153011689 ║  0.49194348866 ║   -  │ 2.86e-08 ║ S  │     4 │ 0.125000 ║     9 │ 3.26e-06   ║
#  135 ║ 0.348678 │  0.17153003384 ║  0.49194327111 ║   -  │ 2.15e-08 ║ S  │     4 │ 0.125000 ║    10 │ 2.17e-06   ║
# Polishing not needed - no active set detected at optimal point
#  136 ║ 0.150095 │  0.07383803997 ║  0.49194311530 ║   -  │ 1.75e-08 ║ S  │     3 │ 0.250000 ║    11 │ 1.58e-06   ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                                            ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                                   ║
# ═════╦═══════════════════════════╦════════════════╦═════════════════╦═══════════════════════╦════════════════════╣
#    F ║          │                ║  0.49194311530 ║   -  │ 1.75e-08 ║    │       │          ║       │            ║
#    B ║          │                ║  0.49194245854 ║   -  │ 1.75e-08 ║    │       │          ║       │            ║
#   MF ║          │                ║  0.61751624522 ║   -  │ 0.000000 ║    │       │          ║       │            ║
# ═════╩═══════════════════════════╩════════════════╩═════════════════╩═══════════════════════╩════════════════════╣
# Iterations:              136                                                                                     ║
# Function evaluations:    410                                                                                     ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy Wolfe conditions at a   ║
# feasible point (to tolerances).  This may be an indication that approximate stationarity has been attained.      ║
# ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# Total Wall Time: 455.80154943466187s
# tensor([1.0000], device='cuda:0', dtype=torch.float64)

# %%
torch.testing.assert_close(
    cpu_soln.final.x,
    cuda_soln.final.x.cpu(),
    atol=1e-5,
    rtol=1e-5,
)
